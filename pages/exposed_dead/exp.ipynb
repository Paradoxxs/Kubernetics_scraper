# %%
import requests
import time
import random
import sqlite3
from bs4 import BeautifulSoup
import re
import random

# %%
conn = sqlite3.connect('exposed.db')
cursor = conn.cursor()
cursor.execute('''CREATE TABLE IF NOT EXISTS forum_urls
            (url TEXT)''')

conn.commit()

# %%
user_agents = [ 
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36', 
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36', 
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36', 
    'Mozilla/5.0 (iPhone; CPU iPhone OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148', 
    'Mozilla/5.0 (Linux; Android 11; SM-G960U) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.72 Mobile Safari/537.36' 
]

# %%
def create_tables(c):
    cursor = c.cursor()
    # Create a table if it doesn't exist
    cursor.execute('''CREATE TABLE IF NOT EXISTS topics
                (url TEXT,title text,author text,replies integer,views integer,last_post text)''')
    c.commit()
    cursor.execute('''CREATE TABLE IF NOT EXISTS posts
                (url TEXT,thread_title text,author text,post_text text,post_order integer,user_id text)''')
    c.commit()
create_tables(conn)

# %%
def scrape_forums(url):
    user_agent = random.choice(user_agents) 
    headers = {'User-Agent': user_agent}
    page = requests.get(url,headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    all_links = soup.find_all("a")
    pattern = re.compile(r".*Forum-.*")
    # Filter and print the links that match the pattern
    for link in all_links:
        href = link.get("href")
        if href and pattern.match(href):
            print(href)
            cursor.execute('''INSERT INTO forum_urls (url) VALUES (?)''', (href,))
            conn.commit()

# %%
scrape_forums("https://exposed.vc/")

# %%
def scrape_topics(soup):
    topics = soup.find_all("tr", class_="inline_row")
    for topic in topics:
        try:
            elements = topic.find_all(class_="trow1")
            topic_url = elements[1].find("a").get("href")
            #print("topic: ",topic_url)
            title = elements[1].find("a").text.strip()
            #print("title: ",title)
            author = elements[1].find("div", class_="author").text.strip()
            #print("author: ",author)
            #replied = elements[2].text.strip()
            #print("replies: ",replied)
            cursor.execute("INSERT or ignore INTO topics VALUES (?,?,?,?,?,?)",(topic_url,title, author, None,None,None))
            conn.commit()
            print(f"Inserted {topic_url}")
        except Exception as e:
            print(e)
            elements = topic.find_all(class_="trow1")
            topic_url = elements[1].find("a").get("href")
            continue

# %%
def scrape_forum_pages(forum_url):
    url = f"https://exposed.vc/{forum_url[0]}"
    print(f"scraping {url}")
    user_agent = random.choice(user_agents) 
    headers = {'User-Agent': user_agent}
    page = requests.get(url,headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    scrape_topics(soup)

    try:
        page_count = int(soup.find(class_="pages").text.strip().split("(")[-1].replace("):", ""))
    except Exception as e:
        page_count = None
        
    # Filter and print the links that match the pattern
    if page_count != None:
        for i in range(2,page_count):
            print(f"scraping page {i}")
            page = requests.get(url+f"?page={i}",headers=headers)
            soup = BeautifulSoup(page.content, 'html.parser')
            scrape_topics(soup)

# %%
cursor.execute("select url from forum_urls ")
rows = cursor.fetchall()
for row in rows:
    scrape_forum_pages(row)
    time.sleep(1)
# Out:
# scraping https://exposed.vc/Forum-Databases
# list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Aston\Documents\GitHub\web_scraper\exposed\exp.ipynb Cell 9 in 6
#       <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> elements = topic.find_all(class_="trow1")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> topic_url = elements[1].find("a").get("href")
#       <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> #print("topic: ",topic_url)
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# c:\Users\Aston\Documents\GitHub\web_scraper\exposed\exp.ipynb Cell 9 in 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> rows = cursor.fetchall()
#       <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> for row in rows:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     scrape_forum_pages(row)
#
# c:\Users\Aston\Documents\GitHub\web_scraper\exposed\exp.ipynb Cell 9 in 8
#       <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> page = requests.get(url,headers=headers)
#       <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> soup = BeautifulSoup(page.content, 'html.parser')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> scrape_topics(soup)
#      <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a> try:
#      <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>     page_count = int(soup.find(class_="pages").text.strip().split("(")[-1].replace("):", ""))
#
# c:\Users\Aston\Documents\GitHub\web_scraper\exposed\exp.ipynb Cell 9 in 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a> print(e)
#      <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=18'>19</a> elements = topic.find_all(class_="trow1")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> topic_url = elements[1].find("a").get("href")
#      <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/exposed/exp.ipynb#X11sZmlsZQ%3D%3D?line=20'>21</a> continue
#
# IndexError: list index out of range
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# url, title, pk
# It only scrape the fist page as I find it the most valuable
def scrape_posts(topic):    
    url = f"https://exposed.vc/{topic[0]}"
    print(f"scraping {url}")
    user_agent = random.choice(user_agents)
    headers = {'User-Agent': user_agent}
    page = requests.get(url,headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    get_topic_timestamp(soup,topic[-1])
    posts = soup.find_all("div", class_="post") 
    for post in posts:
        try:
            username = post.find("div", class_="post__user-profile").text.strip()
            body_text = post.find("div", class_="body").text.strip()
            order = int(post.find(class_="postbit-number").text.strip().replace("#", ""))
            user_id = post.find("div", class_="post__user-profile").find("a").get("href").split("/")[-1]
            cursor.execute("INSERT or ignore INTO posts VALUES (?,?,?,?,?)",(topic[0],topic[1],username,body_text,order))
            conn.commit()
            
        except Exception as e:
            print(e)
            continue
    print(f"Inserted {url}")
def get_topic_timestamp(soup,topic_pk):
    timestamp = soup.find("div" ,class_="showthread-desc").text.strip().split(" - ")[-1]
    #update timestamp of topic using the pk
    cursor.execute("UPDATE topics SET last_post = ? WHERE pk = ?",(timestamp,topic_pk))
    conn.commit()

# %%
#scrape_posts(["Thread-2022-NVIDIA-Employee-database","test"])

cursor.execute("select topics.url,topics.title,topics.pk from topics left join posts on topics.url = posts.url where posts.url is NULL ")
rows = cursor.fetchall()
for row in rows:
    scrape_posts(row)
# Out:
# scraping https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# Inserted https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# scraping https://exposed.vc/Thread-Fun-experiment
# Inserted https://exposed.vc/Thread-Fun-experiment
# scraping https://exposed.vc/Thread-Cracking-software-legally-tutorial
# Inserted https://exposed.vc/Thread-Cracking-software-legally-tutorial
# scraping https://exposed.vc/Thread-Activate-Sublime-Text-4-Build-4143
# Inserted https://exposed.vc/Thread-Activate-Sublime-Text-4-Build-4143
# scraping https://exposed.vc/Thread-SVB-FACEBOOK-FULL-CAPTURE-2023
# Inserted https://exposed.vc/Thread-SVB-FACEBOOK-FULL-CAPTURE-2023
# scraping https://exposed.vc/Thread-Carrefour-with-Full-Capture-Config-SilverBullet-2023
# Inserted https://exposed.vc/Thread-Carrefour-with-Full-Capture-Config-SilverBullet-2023
# scraping https://exposed.vc/Thread-Netflix-with-full-capture-Silverbullet-Config-2023
# Inserted https://exposed.vc/Thread-Netflix-with-full-capture-Silverbullet-Config-2023
# scraping https://exposed.vc/Thread-Roblox-Config-2023-ROBUX-Capture
# Inserted https://exposed.vc/Thread-Roblox-Config-2023-ROBUX-Capture
# scraping https://exposed.vc/Thread-SVB-NETFLIX-API-CONFIG-FULL-CAPTURE-WORKING-2023
# Inserted https://exposed.vc/Thread-SVB-NETFLIX-API-CONFIG-FULL-CAPTURE-WORKING-2023
# scraping https://exposed.vc/Thread-Database-Mal-Pelayanan-Publik-Kota-Pekanbaru
# Inserted https://exposed.vc/Thread-Database-Mal-Pelayanan-Publik-Kota-Pekanbaru
# scraping https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# Inserted https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# scraping https://exposed.vc/Thread-Doxxing-101
# Inserted https://exposed.vc/Thread-Doxxing-101
# scraping https://exposed.vc/Thread-HTML-and-JavaScript-Teacher-Examples-in-HTML-and-JavaScript
# Inserted https://exposed.vc/Thread-HTML-and-JavaScript-Teacher-Examples-in-HTML-and-JavaScript
# scraping https://exposed.vc/Thread-script-Telegram-logs-to-tdata
# Inserted https://exposed.vc/Thread-script-Telegram-logs-to-tdata
# scraping https://exposed.vc/Thread-Python-Website-Analyzer
# Inserted https://exposed.vc/Thread-Python-Website-Analyzer
# scraping https://exposed.vc/Thread-List-of-websites-for-free-RDP-VPS-trials
# Inserted https://exposed.vc/Thread-List-of-websites-for-free-RDP-VPS-trials
# scraping https://exposed.vc/Thread-How-to-Hacking-a-mongoDB-Database-full-tutorial-by-g0d
# Inserted https://exposed.vc/Thread-How-to-Hacking-a-mongoDB-Database-full-tutorial-by-g0d
# scraping https://exposed.vc/Thread-SMALL-OPSEC-TUTORIAL-VPS-DOMAIN-VPN-EMAIL
# Inserted https://exposed.vc/Thread-SMALL-OPSEC-TUTORIAL-VPS-DOMAIN-VPN-EMAIL
# scraping https://exposed.vc/Thread-FREE-Giftcards-Amazon-Netflix-etc
# Inserted https://exposed.vc/Thread-FREE-Giftcards-Amazon-Netflix-etc
# scraping https://exposed.vc/Thread-Quit-being-retarded-101
# Inserted https://exposed.vc/Thread-Quit-being-retarded-101
# scraping https://exposed.vc/Thread-FREE-Giftcards-and-Video-Games
# Inserted https://exposed.vc/Thread-FREE-Giftcards-and-Video-Games
# scraping https://exposed.vc/Thread-UHQ-A-better-and-free-version-of-EPIEOS-that-searches-email-across-diffeent-websites
# Inserted https://exposed.vc/Thread-UHQ-A-better-and-free-version-of-EPIEOS-that-searches-email-across-diffeent-websites
# scraping https://exposed.vc/Thread-Rumble-Hacxx-Underground-Channel
# Inserted https://exposed.vc/Thread-Rumble-Hacxx-Underground-Channel
# scraping https://exposed.vc/Thread-Invideo-Professional-online-video-editing
# Inserted https://exposed.vc/Thread-Invideo-Professional-online-video-editing
# scraping https://exposed.vc/Thread-Search-in-facebook-database
# Inserted https://exposed.vc/Thread-Search-in-facebook-database
# scraping https://exposed.vc/Thread-GUIDE-TO-GETTING-SN-SERIAL-NUMBERS
# Inserted https://exposed.vc/Thread-GUIDE-TO-GETTING-SN-SERIAL-NUMBERS
# scraping https://exposed.vc/Thread-Lnea-A%C3%A9rea-Amaszonas-S-A-data-leak
# Inserted https://exposed.vc/Thread-Lnea-A%C3%A9rea-Amaszonas-S-A-data-leak
# scraping https://exposed.vc/Thread-Medusa-Raas-announcements
# Inserted https://exposed.vc/Thread-Medusa-Raas-announcements
# scraping https://exposed.vc/Thread-lonseal-com-Database-Leaked-Download-Now
# Inserted https://exposed.vc/Thread-lonseal-com-Database-Leaked-Download-Now
# scraping https://exposed.vc/Thread-BERGHOF-0DAY
# Inserted https://exposed.vc/Thread-BERGHOF-0DAY
# scraping https://exposed.vc/Thread-Etecsa-Cuban-telecom-dump
# Inserted https://exposed.vc/Thread-Etecsa-Cuban-telecom-dump
# scraping https://exposed.vc/Thread-Scam-Report-Posting-Format
# Inserted https://exposed.vc/Thread-Scam-Report-Posting-Format
# scraping https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# Inserted https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# scraping https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# Inserted https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# scraping https://exposed.vc/Thread-Fun-experiment
# Inserted https://exposed.vc/Thread-Fun-experiment
# scraping https://exposed.vc/Thread-Cracking-software-legally-tutorial
# Inserted https://exposed.vc/Thread-Cracking-software-legally-tutorial
# scraping https://exposed.vc/Thread-Activate-Sublime-Text-4-Build-4143
# Inserted https://exposed.vc/Thread-Activate-Sublime-Text-4-Build-4143
# scraping https://exposed.vc/Thread-SVB-FACEBOOK-FULL-CAPTURE-2023
# Inserted https://exposed.vc/Thread-SVB-FACEBOOK-FULL-CAPTURE-2023
# scraping https://exposed.vc/Thread-Carrefour-with-Full-Capture-Config-SilverBullet-2023
# Inserted https://exposed.vc/Thread-Carrefour-with-Full-Capture-Config-SilverBullet-2023
# scraping https://exposed.vc/Thread-Netflix-with-full-capture-Silverbullet-Config-2023
# Inserted https://exposed.vc/Thread-Netflix-with-full-capture-Silverbullet-Config-2023
# scraping https://exposed.vc/Thread-Roblox-Config-2023-ROBUX-Capture
# Inserted https://exposed.vc/Thread-Roblox-Config-2023-ROBUX-Capture
# scraping https://exposed.vc/Thread-SVB-NETFLIX-API-CONFIG-FULL-CAPTURE-WORKING-2023
# Inserted https://exposed.vc/Thread-SVB-NETFLIX-API-CONFIG-FULL-CAPTURE-WORKING-2023
# scraping https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# Inserted https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# scraping https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# Inserted https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# scraping https://exposed.vc/Thread-Doxxing-101
# Inserted https://exposed.vc/Thread-Doxxing-101
# scraping https://exposed.vc/Thread-HTML-and-JavaScript-Teacher-Examples-in-HTML-and-JavaScript
# Inserted https://exposed.vc/Thread-HTML-and-JavaScript-Teacher-Examples-in-HTML-and-JavaScript
# scraping https://exposed.vc/Thread-script-Telegram-logs-to-tdata
# Inserted https://exposed.vc/Thread-script-Telegram-logs-to-tdata
# scraping https://exposed.vc/Thread-Python-Website-Analyzer
# Inserted https://exposed.vc/Thread-Python-Website-Analyzer
# scraping https://exposed.vc/Thread-List-of-websites-for-free-RDP-VPS-trials
# Inserted https://exposed.vc/Thread-List-of-websites-for-free-RDP-VPS-trials
# scraping https://exposed.vc/Thread-How-to-Hacking-a-mongoDB-Database-full-tutorial-by-g0d
# Inserted https://exposed.vc/Thread-How-to-Hacking-a-mongoDB-Database-full-tutorial-by-g0d
# scraping https://exposed.vc/Thread-SMALL-OPSEC-TUTORIAL-VPS-DOMAIN-VPN-EMAIL
# Inserted https://exposed.vc/Thread-SMALL-OPSEC-TUTORIAL-VPS-DOMAIN-VPN-EMAIL
# scraping https://exposed.vc/Thread-FREE-Giftcards-Amazon-Netflix-etc
# Inserted https://exposed.vc/Thread-FREE-Giftcards-Amazon-Netflix-etc
# scraping https://exposed.vc/Thread-Quit-being-retarded-101
# Inserted https://exposed.vc/Thread-Quit-being-retarded-101
# scraping https://exposed.vc/Thread-FREE-Giftcards-and-Video-Games
# Inserted https://exposed.vc/Thread-FREE-Giftcards-and-Video-Games
# scraping https://exposed.vc/Thread-UHQ-A-better-and-free-version-of-EPIEOS-that-searches-email-across-diffeent-websites
# Inserted https://exposed.vc/Thread-UHQ-A-better-and-free-version-of-EPIEOS-that-searches-email-across-diffeent-websites
# scraping https://exposed.vc/Thread-Rumble-Hacxx-Underground-Channel
# Inserted https://exposed.vc/Thread-Rumble-Hacxx-Underground-Channel
# scraping https://exposed.vc/Thread-Invideo-Professional-online-video-editing
# Inserted https://exposed.vc/Thread-Invideo-Professional-online-video-editing
# scraping https://exposed.vc/Thread-Search-in-facebook-database
# Inserted https://exposed.vc/Thread-Search-in-facebook-database
# scraping https://exposed.vc/Thread-GUIDE-TO-GETTING-SN-SERIAL-NUMBERS
# Inserted https://exposed.vc/Thread-GUIDE-TO-GETTING-SN-SERIAL-NUMBERS
# scraping https://exposed.vc/Thread-Lnea-A%C3%A9rea-Amaszonas-S-A-data-leak
# Inserted https://exposed.vc/Thread-Lnea-A%C3%A9rea-Amaszonas-S-A-data-leak
# scraping https://exposed.vc/Thread-Medusa-Raas-announcements
# Inserted https://exposed.vc/Thread-Medusa-Raas-announcements
# scraping https://exposed.vc/Thread-lonseal-com-Database-Leaked-Download-Now
# Inserted https://exposed.vc/Thread-lonseal-com-Database-Leaked-Download-Now
# scraping https://exposed.vc/Thread-BERGHOF-0DAY
# Inserted https://exposed.vc/Thread-BERGHOF-0DAY
# scraping https://exposed.vc/Thread-Etecsa-Cuban-telecom-dump
# Inserted https://exposed.vc/Thread-Etecsa-Cuban-telecom-dump
# scraping https://exposed.vc/Thread-Scam-Report-Posting-Format
# Inserted https://exposed.vc/Thread-Scam-Report-Posting-Format
# scraping https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# Inserted https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# scraping https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# Inserted https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# scraping https://exposed.vc/Thread-Fun-experiment
# Inserted https://exposed.vc/Thread-Fun-experiment
# scraping https://exposed.vc/Thread-Cracking-software-legally-tutorial
# Inserted https://exposed.vc/Thread-Cracking-software-legally-tutorial
# scraping https://exposed.vc/Thread-Activate-Sublime-Text-4-Build-4143
# Inserted https://exposed.vc/Thread-Activate-Sublime-Text-4-Build-4143
# scraping https://exposed.vc/Thread-SVB-FACEBOOK-FULL-CAPTURE-2023
# Inserted https://exposed.vc/Thread-SVB-FACEBOOK-FULL-CAPTURE-2023
# scraping https://exposed.vc/Thread-Carrefour-with-Full-Capture-Config-SilverBullet-2023
# Inserted https://exposed.vc/Thread-Carrefour-with-Full-Capture-Config-SilverBullet-2023
# scraping https://exposed.vc/Thread-Netflix-with-full-capture-Silverbullet-Config-2023
# Inserted https://exposed.vc/Thread-Netflix-with-full-capture-Silverbullet-Config-2023
# scraping https://exposed.vc/Thread-Roblox-Config-2023-ROBUX-Capture
# Inserted https://exposed.vc/Thread-Roblox-Config-2023-ROBUX-Capture
# scraping https://exposed.vc/Thread-SVB-NETFLIX-API-CONFIG-FULL-CAPTURE-WORKING-2023
# Inserted https://exposed.vc/Thread-SVB-NETFLIX-API-CONFIG-FULL-CAPTURE-WORKING-2023
# scraping https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# Inserted https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# scraping https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# Inserted https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# scraping https://exposed.vc/Thread-Doxxing-101
# Inserted https://exposed.vc/Thread-Doxxing-101
# scraping https://exposed.vc/Thread-HTML-and-JavaScript-Teacher-Examples-in-HTML-and-JavaScript
# Inserted https://exposed.vc/Thread-HTML-and-JavaScript-Teacher-Examples-in-HTML-and-JavaScript
# scraping https://exposed.vc/Thread-script-Telegram-logs-to-tdata
# Inserted https://exposed.vc/Thread-script-Telegram-logs-to-tdata
# scraping https://exposed.vc/Thread-Python-Website-Analyzer
# Inserted https://exposed.vc/Thread-Python-Website-Analyzer
# scraping https://exposed.vc/Thread-List-of-websites-for-free-RDP-VPS-trials
# Inserted https://exposed.vc/Thread-List-of-websites-for-free-RDP-VPS-trials
# scraping https://exposed.vc/Thread-How-to-Hacking-a-mongoDB-Database-full-tutorial-by-g0d
# Inserted https://exposed.vc/Thread-How-to-Hacking-a-mongoDB-Database-full-tutorial-by-g0d
# scraping https://exposed.vc/Thread-SMALL-OPSEC-TUTORIAL-VPS-DOMAIN-VPN-EMAIL
# Inserted https://exposed.vc/Thread-SMALL-OPSEC-TUTORIAL-VPS-DOMAIN-VPN-EMAIL
# scraping https://exposed.vc/Thread-FREE-Giftcards-Amazon-Netflix-etc
# Inserted https://exposed.vc/Thread-FREE-Giftcards-Amazon-Netflix-etc
# scraping https://exposed.vc/Thread-Quit-being-retarded-101
# Inserted https://exposed.vc/Thread-Quit-being-retarded-101
# scraping https://exposed.vc/Thread-FREE-Giftcards-and-Video-Games
# Inserted https://exposed.vc/Thread-FREE-Giftcards-and-Video-Games
# scraping https://exposed.vc/Thread-UHQ-A-better-and-free-version-of-EPIEOS-that-searches-email-across-diffeent-websites
# Inserted https://exposed.vc/Thread-UHQ-A-better-and-free-version-of-EPIEOS-that-searches-email-across-diffeent-websites
# scraping https://exposed.vc/Thread-Rumble-Hacxx-Underground-Channel
# Inserted https://exposed.vc/Thread-Rumble-Hacxx-Underground-Channel
# scraping https://exposed.vc/Thread-Invideo-Professional-online-video-editing
# Inserted https://exposed.vc/Thread-Invideo-Professional-online-video-editing
# scraping https://exposed.vc/Thread-Search-in-facebook-database
# Inserted https://exposed.vc/Thread-Search-in-facebook-database
# scraping https://exposed.vc/Thread-GUIDE-TO-GETTING-SN-SERIAL-NUMBERS
# Inserted https://exposed.vc/Thread-GUIDE-TO-GETTING-SN-SERIAL-NUMBERS
# scraping https://exposed.vc/Thread-Lnea-A%C3%A9rea-Amaszonas-S-A-data-leak
# Inserted https://exposed.vc/Thread-Lnea-A%C3%A9rea-Amaszonas-S-A-data-leak
# scraping https://exposed.vc/Thread-Medusa-Raas-announcements
# Inserted https://exposed.vc/Thread-Medusa-Raas-announcements
# scraping https://exposed.vc/Thread-lonseal-com-Database-Leaked-Download-Now
# Inserted https://exposed.vc/Thread-lonseal-com-Database-Leaked-Download-Now
# scraping https://exposed.vc/Thread-BERGHOF-0DAY
# Inserted https://exposed.vc/Thread-BERGHOF-0DAY
# scraping https://exposed.vc/Thread-Etecsa-Cuban-telecom-dump
# Inserted https://exposed.vc/Thread-Etecsa-Cuban-telecom-dump
# scraping https://exposed.vc/Thread-Scam-Report-Posting-Format
# Inserted https://exposed.vc/Thread-Scam-Report-Posting-Format
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# Inserted https://exposed.vc/Thread-LOOKING-FOR-VIBER-CHEKER
# scraping https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# Inserted https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# scraping https://exposed.vc/Thread-BUYING-Looking-for-any-politics-military-technological-intelligence-well-paid--736
# Inserted https://exposed.vc/Thread-BUYING-Looking-for-any-politics-military-technological-intelligence-well-paid--736
# scraping https://exposed.vc/Thread-BUYING-Stealer-crypto-logs
# Inserted https://exposed.vc/Thread-BUYING-Stealer-crypto-logs
# scraping https://exposed.vc/Thread-BUYING-EU-INVALID-MAIL-PASS
# Inserted https://exposed.vc/Thread-BUYING-EU-INVALID-MAIL-PASS
# scraping https://exposed.vc/Thread-BUYING-Bulk-FA-Netflix-accounts-with-Mail-Access
# Inserted https://exposed.vc/Thread-BUYING-Bulk-FA-Netflix-accounts-with-Mail-Access
# scraping https://exposed.vc/Thread-BUYING-about-china--1710
# Inserted https://exposed.vc/Thread-BUYING-about-china--1710
# scraping https://exposed.vc/Thread-BUYING-LOOK-FOR-EUROPEAN-EMAIL-PASSWORD-COMBINATION-LIST-GERMANY-FRANCE-ITALY-SPAIN
# Inserted https://exposed.vc/Thread-BUYING-LOOK-FOR-EUROPEAN-EMAIL-PASSWORD-COMBINATION-LIST-GERMANY-FRANCE-ITALY-SPAIN
# scraping https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# Inserted https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# scraping https://exposed.vc/Thread-Fun-experiment
# Inserted https://exposed.vc/Thread-Fun-experiment
# scraping https://exposed.vc/Thread-Cracking-software-legally-tutorial
# Inserted https://exposed.vc/Thread-Cracking-software-legally-tutorial
# scraping https://exposed.vc/Thread-Activate-Sublime-Text-4-Build-4143
# Inserted https://exposed.vc/Thread-Activate-Sublime-Text-4-Build-4143
# scraping https://exposed.vc/Thread-SVB-FACEBOOK-FULL-CAPTURE-2023
# Inserted https://exposed.vc/Thread-SVB-FACEBOOK-FULL-CAPTURE-2023
# scraping https://exposed.vc/Thread-Carrefour-with-Full-Capture-Config-SilverBullet-2023
# Inserted https://exposed.vc/Thread-Carrefour-with-Full-Capture-Config-SilverBullet-2023
# scraping https://exposed.vc/Thread-Netflix-with-full-capture-Silverbullet-Config-2023
# Inserted https://exposed.vc/Thread-Netflix-with-full-capture-Silverbullet-Config-2023
# scraping https://exposed.vc/Thread-Roblox-Config-2023-ROBUX-Capture
# Inserted https://exposed.vc/Thread-Roblox-Config-2023-ROBUX-Capture
# scraping https://exposed.vc/Thread-SVB-NETFLIX-API-CONFIG-FULL-CAPTURE-WORKING-2023
# Inserted https://exposed.vc/Thread-SVB-NETFLIX-API-CONFIG-FULL-CAPTURE-WORKING-2023
# scraping https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# Inserted https://exposed.vc/Thread-Bot-of-Legends-Database-Leaked-Download
# scraping https://exposed.vc/Thread-BUYING-Looking-for-any-politics-military-technological-intelligence-well-paid--736
# Inserted https://exposed.vc/Thread-BUYING-Looking-for-any-politics-military-technological-intelligence-well-paid--736
# scraping https://exposed.vc/Thread-BUYING-Stealer-crypto-logs
# Inserted https://exposed.vc/Thread-BUYING-Stealer-crypto-logs
# scraping https://exposed.vc/Thread-BUYING-EU-INVALID-MAIL-PASS
# Inserted https://exposed.vc/Thread-BUYING-EU-INVALID-MAIL-PASS
# scraping https://exposed.vc/Thread-BUYING-Bulk-FA-Netflix-accounts-with-Mail-Access
# Inserted https://exposed.vc/Thread-BUYING-Bulk-FA-Netflix-accounts-with-Mail-Access
# scraping https://exposed.vc/Thread-BUYING-about-china--1710
# Inserted https://exposed.vc/Thread-BUYING-about-china--1710
# scraping https://exposed.vc/Thread-BUYING-LOOK-FOR-EUROPEAN-EMAIL-PASSWORD-COMBINATION-LIST-GERMANY-FRANCE-ITALY-SPAIN
# Inserted https://exposed.vc/Thread-BUYING-LOOK-FOR-EUROPEAN-EMAIL-PASSWORD-COMBINATION-LIST-GERMANY-FRANCE-ITALY-SPAIN
# scraping https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# Inserted https://exposed.vc/Thread-BUYING-portugal-and-brazil-police
# scraping https://exposed.vc/Thread-Doxxing-101
# Inserted https://exposed.vc/Thread-Doxxing-101
# scraping https://exposed.vc/Thread-HTML-and-JavaScript-Teacher-Examples-in-HTML-and-JavaScript
# Inserted https://exposed.vc/Thread-HTML-and-JavaScript-Teacher-Examples-in-HTML-and-JavaScript
# scraping https://exposed.vc/Thread-script-Telegram-logs-to-tdata
# Inserted https://exposed.vc/Thread-script-Telegram-logs-to-tdata
# scraping https://exposed.vc/Thread-Python-Website-Analyzer
# Inserted https://exposed.vc/Thread-Python-Website-Analyzer
# scraping https://exposed.vc/Thread-List-of-websites-for-free-RDP-VPS-trials
# Inserted https://exposed.vc/Thread-List-of-websites-for-free-RDP-VPS-trials
# scraping https://exposed.vc/Thread-How-to-Hacking-a-mongoDB-Database-full-tutorial-by-g0d
# Inserted https://exposed.vc/Thread-How-to-Hacking-a-mongoDB-Database-full-tutorial-by-g0d
# scraping https://exposed.vc/Thread-SMALL-OPSEC-TUTORIAL-VPS-DOMAIN-VPN-EMAIL
# Inserted https://exposed.vc/Thread-SMALL-OPSEC-TUTORIAL-VPS-DOMAIN-VPN-EMAIL
# scraping https://exposed.vc/Thread-FREE-Giftcards-Amazon-Netflix-etc
# Inserted https://exposed.vc/Thread-FREE-Giftcards-Amazon-Netflix-etc
# scraping https://exposed.vc/Thread-Quit-being-retarded-101
# Inserted https://exposed.vc/Thread-Quit-being-retarded-101
# scraping https://exposed.vc/Thread-FREE-Giftcards-and-Video-Games
# Inserted https://exposed.vc/Thread-FREE-Giftcards-and-Video-Games
# scraping https://exposed.vc/Thread-UHQ-A-better-and-free-version-of-EPIEOS-that-searches-email-across-diffeent-websites
# Inserted https://exposed.vc/Thread-UHQ-A-better-and-free-version-of-EPIEOS-that-searches-email-across-diffeent-websites
# scraping https://exposed.vc/Thread-Rumble-Hacxx-Underground-Channel
# Inserted https://exposed.vc/Thread-Rumble-Hacxx-Underground-Channel
# scraping https://exposed.vc/Thread-Invideo-Professional-online-video-editing
# Inserted https://exposed.vc/Thread-Invideo-Professional-online-video-editing
# scraping https://exposed.vc/Thread-Search-in-facebook-database
# Inserted https://exposed.vc/Thread-Search-in-facebook-database
# scraping https://exposed.vc/Thread-GUIDE-TO-GETTING-SN-SERIAL-NUMBERS
# Inserted https://exposed.vc/Thread-GUIDE-TO-GETTING-SN-SERIAL-NUMBERS
# scraping https://exposed.vc/Thread-Lnea-A%C3%A9rea-Amaszonas-S-A-data-leak
# Inserted https://exposed.vc/Thread-Lnea-A%C3%A9rea-Amaszonas-S-A-data-leak
# scraping https://exposed.vc/Thread-Medusa-Raas-announcements
# Inserted https://exposed.vc/Thread-Medusa-Raas-announcements
# scraping https://exposed.vc/Thread-lonseal-com-Database-Leaked-Download-Now
# Inserted https://exposed.vc/Thread-lonseal-com-Database-Leaked-Download-Now
# scraping https://exposed.vc/Thread-BERGHOF-0DAY
# Inserted https://exposed.vc/Thread-BERGHOF-0DAY
# scraping https://exposed.vc/Thread-Etecsa-Cuban-telecom-dump
# Inserted https://exposed.vc/Thread-Etecsa-Cuban-telecom-dump
# scraping https://exposed.vc/Thread-Scam-Report-Posting-Format
# Inserted https://exposed.vc/Thread-Scam-Report-Posting-Format
