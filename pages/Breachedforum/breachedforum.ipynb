# %%
import requests
import time
import random
import sqlite3
from bs4 import BeautifulSoup
import re
import random


user_agents = [ 
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36', 
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36', 
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36', 
    'Mozilla/5.0 (iPhone; CPU iPhone OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148', 
    'Mozilla/5.0 (Linux; Android 11; SM-G960U) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.72 Mobile Safari/537.36' 
]


conn = sqlite3.connect('breachforum.db')
cursor = conn.cursor()
cursor.execute('''CREATE TABLE IF NOT EXISTS forum_urls
                (id INTEGER PRIMARY KEY AUTOINCREMENT,
                url TEXT)''')


conn.commit()

url = "https://breachforums.vc/"

# %%
def scrape_forums(url):
    user_agent = random.choice(user_agents) 
    headers = {'User-Agent': user_agent}
    page = requests.get(url,headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    all_links = soup.find_all("a")
    pattern = re.compile(r".*Forum-.*")
    # Filter and print the links that match the pattern
    for link in all_links:
        href = link.get("href")
        if href and pattern.match(href):
            print(href)
            cursor.execute('''INSERT INTO forum_urls (url) VALUES (?)''', (href,))
            conn.commit()

scrape_forums(url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Aston\Documents\GitHub\web_scraper\Breachedforum\breachedforum.ipynb Cell 2 in <cell line: 16>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/Breachedforum/breachedforum.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a>             cursor.execute('''INSERT INTO forum_urls (url) VALUES (?)''', (href,))
#      <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/Breachedforum/breachedforum.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a>             conn.commit()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/Breachedforum/breachedforum.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a> scrape_forums(url)
#
# c:\Users\Aston\Documents\GitHub\web_scraper\Breachedforum\breachedforum.ipynb Cell 2 in scrape_forums(url)
#       <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/Breachedforum/breachedforum.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> user_agent = random.choice(user_agents)
#       <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/Breachedforum/breachedforum.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> headers = {'User-Agent': user_agent}
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/Breachedforum/breachedforum.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> page = requests.get(url,headers=headers)
#       <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/Breachedforum/breachedforum.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> soup = BeautifulSoup(page.content, 'html.parser')
#       <a href='vscode-notebook-cell:/c%3A/Users/Aston/Documents/GitHub/web_scraper/Breachedforum/breachedforum.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> all_links = soup.find_all("a")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def create_tables(c):
    cursor = c.cursor()
    # Create a table if it doesn't exist
    cursor.execute('''CREATE TABLE IF NOT EXISTS topics
                (url TEXT,title text,user_id text,author text)''')
    
    cursor.execute('''CREATE TABLE IF NOT EXISTS posts 
                (url TEXT,thread_title text,author text,post_text text,post_order integer,user_id text)''')
    c.commit()
create_tables(conn)

# %%
def scrape_topics(soup):
    topics = soup.find_all("tr", class_="inline_row")
    for topic in topics:
        try:
            elements = topic.find_all(class_="trow2")
            if elements is None:
              elements = topic.find_all(class_="trow1") 
            
            topic_url = elements[1].find("span", class_="subject_new").find("a").get("href")
            print("topic: ",topic_url)
            title = elements[1].find("span", class_="subject_new").find("a").text.strip()
            print("title: ",title)
            user_id = elements[1].find("span", class_="author").find("a").get("href").split("/")[-1]
            author = elements[1].find("span", class_="author").text.strip().split(" ")[-1].replace(",", "")
            print("author: ",author)
            cursor.execute("INSERT or ignore INTO topics VALUES (?,?,?,?)",(topic_url,title,user_id, author))
            conn.commit()
            print(f"Inserted {topic_url}")
        except Exception as e:
            print(e)
            continue



def scrape_forum_pages(forum_url):
    url = f"https://breachforums.vc/{forum_url[0]}"
    print(f"scraping {url}")
    user_agent = random.choice(user_agents) 
    headers = {'User-Agent': user_agent}
    page = requests.get(url,headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    scrape_topics(soup)

#Because I have already scraped all pages I will only scrape the fist page, as there no need for dublicate threads
"""
    try:
        page_count = int(soup.find(class_="pages").text.strip().split("(")[-1].replace("):", ""))
    except Exception as e:
        page_count = None
        
    # Filter and print the links that match the pattern
    if page_count != None:
        
        for i in range(2,page_count):
            print(f"scraping page {i}")
            page = requests.get(url+f"?page={i}",headers=headers)
            soup = BeautifulSoup(page.content, 'html.parser')
            scrape_topics(soup)
             """
# Out:
# '\n    try:\n        page_count = int(soup.find(class_="pages").text.strip().split("(")[-1].replace("):", ""))\n    except Exception as e:\n        page_count = None\n        \n    # Filter and print the links that match the pattern\n    if page_count != None:\n        \n        for i in range(2,page_count):\n            print(f"scraping page {i}")\n            page = requests.get(url+f"?page={i}",headers=headers)\n            soup = BeautifulSoup(page.content, \'html.parser\')\n            scrape_topics(soup)\n             '

# %%
cursor.execute("select url from forum_urls ")
rows = cursor.fetchall()
for row in rows:
    scrape_forum_pages(row)
    time.sleep(5)
# Out:
# scraping https://breachforums.vc/Forum-Announcements
# topic:  Thread-IMPORTANT-READ-Statement-regarding-Sebastien
# title:  Statement regarding Sebastien
# author:  ShinyHunters
# Inserted Thread-IMPORTANT-READ-Statement-regarding-Sebastien
# list index out of range
# topic:  Thread-IMPORTANT-READ-Regarding-old-BreachForums-domains
# title:  Regarding old BreachForums domains.
# author:  Baphomet
# Inserted Thread-IMPORTANT-READ-Regarding-old-BreachForums-domains
# scraping https://breachforums.vc/Forum-Suggestions-Bug-Reports
# list index out of range
# topic:  Thread-Fix-shoutbox-autoscroll
# title:  Fix shoutbox autoscroll
# author:  kilob
# Inserted Thread-Fix-shoutbox-autoscroll
# list index out of range
# topic:  Thread-Suggestion-reinstate-credit-owners-for-previously-supplied-breaches
# title:  Suggestion: reinstate credit-owners for previously supplied breaches
# author:  maraud3r
# Inserted Thread-Suggestion-reinstate-credit-owners-for-previously-supplied-breaches
# list index out of range
# topic:  Thread-GOD-lounge
# title:  GOD lounge
# author:  kilob
# Inserted Thread-GOD-lounge
# list index out of range
# topic:  Thread-SUGGESTION-Give-me-the-God-username-back
# title:  SUGGESTION: Give me the @God username back
# author:  Sneed
# Inserted Thread-SUGGESTION-Give-me-the-God-username-back
# list index out of range
# topic:  Thread-Can-t-set-a-matrix-homeserver
# title:  Can't set a matrix homeserver
# author:  Jewerslvt
# Inserted Thread-Can-t-set-a-matrix-homeserver
# list index out of range
# topic:  Thread-Alert-when-tagged-in-a-post
# title:  Alert when tagged in a post
# author:  kilob
# Inserted Thread-Alert-when-tagged-in-a-post
# list index out of range
# topic:  Thread-Ability-to-report-closed-threads
# title:  Ability to report closed threads
# author:  kilob
# Inserted Thread-Ability-to-report-closed-threads
# list index out of range
# topic:  Thread-Award-notification
# title:  Award notification
# author:  kilob
# Inserted Thread-Award-notification
# list index out of range
# topic:  Thread-Malware-and-Reverse-Engineering-Suggestion
# title:  Malware and Reverse Engineering Suggestion
# author:  0x27
# Inserted Thread-Malware-and-Reverse-Engineering-Suggestion
# list index out of range
# topic:  Thread-credit-system
# title:  credit system
# author:  moonman
# Inserted Thread-credit-system
# scraping https://breachforums.vc/Forum-Introductions
# list index out of range
# topic:  Thread-Heeeey-yaaaaaalllll
# title:  Heeeey yaaaaaalllll
# author:  SpotnikSignal
# Inserted Thread-Heeeey-yaaaaaalllll
# list index out of range
# topic:  Thread-sentient-here
# title:  sentient here
# author:  Sentient
# Inserted Thread-sentient-here
# list index out of range
# topic:  Thread-Forgot-to-post-introduction
# title:  Forgot to post introduction
# author:  HackingRealm
# Inserted Thread-Forgot-to-post-introduction
# list index out of range
# topic:  Thread-Hi--69180
# title:  Hi!
# author:  Oreo
# Inserted Thread-Hi--69180
# list index out of range
# topic:  Thread-self-introduction
# title:  self introduction!
# author:  aihkw
# Inserted Thread-self-introduction
# list index out of range
# topic:  Thread-Hallo-Wereld-%E3%83%BB%E4%BA%BA%E3%83%BB
# title:  Hallo Wereld (・人・)
# author:  Jewerslvt
# Inserted Thread-Hallo-Wereld-%E3%83%BB%E4%BA%BA%E3%83%BB
# list index out of range
# topic:  Thread-finally-home-safe
# title:  finally, home safe
# author:  angrydave
# Inserted Thread-finally-home-safe
# list index out of range
# topic:  Thread-Welcome-back--68751
# title:  Welcome back
# author:  PyroTech
# Inserted Thread-Welcome-back--68751
# list index out of range
# topic:  Thread-Hi--68757
# title:  Hi!
# author:  joepa
# Inserted Thread-Hi--68757
# list index out of range
# topic:  Thread-Hello-everyone--68779
# title:  Hello everyone
# author:  DudeDoodediDoodle
# Inserted Thread-Hello-everyone--68779
# scraping https://breachforums.vc/Forum-World-News
# topic:  Thread-Current-Wars
# title:  Current Wars.
# author:  opsectard
# Inserted Thread-Current-Wars
# list index out of range
# topic:  Thread-Exposed-VC-SEIZED
# title:  Exposed.VC - SEIZED!
# author:  Mioko
# Inserted Thread-Exposed-VC-SEIZED
# list index out of range
# topic:  Thread-10M-REWARD
# title:  $10M REWARD !!!
# author:  kurdo
# Inserted Thread-10M-REWARD
# list index out of range
# topic:  Thread-Attacks-targeting-European-Banking-Systems-Cooming-Soon
# title:  Attacks targeting European Banking Systems. Cooming Soon :)
# author:  Calypso
# Inserted Thread-Attacks-targeting-European-Banking-Systems-Cooming-Soon
# list index out of range
# topic:  Thread-War-in-Ukraine
# title:  War in Ukraine
# author:  blackboar
# Inserted Thread-War-in-Ukraine
# list index out of range
# topic:  Thread-What-are-your-thoughts-on-the-latest-UFO-News
# title:  What are your thoughts on the latest UFO News? ?
# author:  Tofu
# Inserted Thread-What-are-your-thoughts-on-the-latest-UFO-News
# list index out of range
# topic:  Thread-CVE-2023-32315-Openfire-Admin-Console-Auth-Bypass
# title:  CVE-2023-32315 Openfire Admin Console Auth Bypass
# author:  etc
# Inserted Thread-CVE-2023-32315-Openfire-Admin-Console-Auth-Bypass
# list index out of range
# topic:  Thread-War-footage-updates-source-website
# title:  War footage/updates source website
# author:  kilob
# Inserted Thread-War-footage-updates-source-website
# list index out of range
# scraping https://breachforums.vc/Forum-Technology-News
# list index out of range
# topic:  Thread-Tor-Deanonymization
# title:  Tor Deanonymization
# author:  DissentDoe
# Inserted Thread-Tor-Deanonymization
# list index out of range
# topic:  Thread-A-lockbit-Member-Arrested-Today
# title:  A lockbit Member Arrested Today
# author:  kurdo
# Inserted Thread-A-lockbit-Member-Arrested-Today
# list index out of range
# topic:  Thread-IPhone-14-Is-it-worth-it
# title:  IPhone 14 : Is it worth it?
# author:  En3ronthegreat
# Inserted Thread-IPhone-14-Is-it-worth-it
# list index out of range
# scraping https://breachforums.vc/Forum-The-Lounge
# topic:  Thread-what-s-the-best-file-transfer-alternative-to-anonfiles
# title:  what's the best file transfer alternative to anonfiles?
# author:  Stony
# Inserted Thread-what-s-the-best-file-transfer-alternative-to-anonfiles
# list index out of range
# topic:  Thread-I-AM-BACK
# title:  I AM BACK
# author:  Dacoke
# Inserted Thread-I-AM-BACK
# list index out of range
# topic:  Thread-there-should-be-an-onion-web
# title:  there should be an onion web
# author:  Stony
# Inserted Thread-there-should-be-an-onion-web
# list index out of range
# topic:  Thread-PROOF-BREACHED-VC-IS-BEING-RAN-BY-THE-FEDS
# title:  PROOF BREACHED.VC IS BEING RAN BY THE FEDS
# author:  emo
# Inserted Thread-PROOF-BREACHED-VC-IS-BEING-RAN-BY-THE-FEDS
# list index out of range
# topic:  Thread-How-to-add-paid-link-in-post
# title:  How to add paid link in post?
# author:  cateye84
# Inserted Thread-How-to-add-paid-link-in-post
# list index out of range
# topic:  Thread-is-proxies-fo-legit
# title:  is proxies.fo legit
# author:  rich
# Inserted Thread-is-proxies-fo-legit
# list index out of range
# topic:  Thread-Is-Buying-Logs-Worth-it
# title:  Is Buying Logs Worth it?
# author:  GoodFella
# Inserted Thread-Is-Buying-Logs-Worth-it
# list index out of range
# topic:  Thread-I-can-t-understand-this
# title:  I can't understand this
# author:  vinpetrol
# Inserted Thread-I-can-t-understand-this
# list index out of range
# topic:  Thread-Cops-murder-caveman
# title:  Cops murder caveman
# author:  kilob
# Inserted Thread-Cops-murder-caveman
# list index out of range
# topic:  Thread-ShinyHunters-kill-yourself
# title:  @ShinyHunters kill yourself
# author:  kilob
# Inserted Thread-ShinyHunters-kill-yourself
# list index out of range
# scraping https://breachforums.vc/Forum-Serious-Discussion
# list index out of range
# topic:  Thread-Weight-loss-tips
# title:  Weight loss tips?
# author:  kilob
# Inserted Thread-Weight-loss-tips
# list index out of range
# topic:  Thread-Tor-vs-I2p
# title:  Tor vs I2p
# author:  telturn
# Inserted Thread-Tor-vs-I2p
# list index out of range
# topic:  Thread-Cat
# title:  Cat
# author:  Cat
# Inserted Thread-Cat
# list index out of range
# topic:  Thread-Scammers-no-staff-online
# title:  Scammers & no staff online
# author:  kilob
# Inserted Thread-Scammers-no-staff-online
# list index out of range
# topic:  Thread-Anal-sex
# title:  Anal sex...
# author:  kilob
# Inserted Thread-Anal-sex
# list index out of range
# topic:  Thread-Website-went-down-for-2-minutes
# title:  Website went down for 2 minutes
# author:  Maxwell-Frost
# Inserted Thread-Website-went-down-for-2-minutes
# list index out of range
# topic:  Thread-am-i-wrong
# title:  am i wrong?
# author:  puppy
# Inserted Thread-am-i-wrong
# list index out of range
# topic:  Thread-Suggestion-to-Discuss
# title:  Suggestion to Discuss
# author:  Hack
# Inserted Thread-Suggestion-to-Discuss
# list index out of range
# topic:  Thread-Shoutbox-emoji-suggestion
# title:  Shoutbox emoji suggestion
# author:  entrypoint78
# Inserted Thread-Shoutbox-emoji-suggestion
# list index out of range
# scraping https://breachforums.vc/Forum-Anime-Manga
# list index out of range
# topic:  Thread-Anime-Alert
# title:  Anime Alert
# author:  testing
# Inserted Thread-Anime-Alert
# list index out of range
# topic:  Thread-Direct-Download-My-Hero-Academia-Anime-1080p-Dual-Audio
# title:  Direct Download - My Hero Academia Anime 1080p Dual Audio
# author:  Snorlax
# Inserted Thread-Direct-Download-My-Hero-Academia-Anime-1080p-Dual-Audio
# list index out of range
# topic:  Thread-Thoughts-on-Oshi-No-Ko
# title:  Thoughts on Oshi No Ko
# author:  AltairX
# Inserted Thread-Thoughts-on-Oshi-No-Ko
# list index out of range
# topic:  Thread-This-Category-is-too-quiet
# title:  This Category is too quiet
# author:  r1ddikulu5
# Inserted Thread-This-Category-is-too-quiet
# list index out of range
# topic:  Thread-Direct-Download-Bleach-Anime-All-Seasons-1080p-Dual-Audio
# title:  Direct Download - Bleach Anime All Seasons 1080p Dual Audio
# author:  Snorlax
# Inserted Thread-Direct-Download-Bleach-Anime-All-Seasons-1080p-Dual-Audio
# list index out of range
# topic:  Thread-Recommend-anime-similar-to-ghost-in-the-shell
# title:  Recommend anime similar to ghost in the shell
# author:  capt
# Inserted Thread-Recommend-anime-similar-to-ghost-in-the-shell
# list index out of range
# topic:  Thread-What-do-you-think-is-the-dumbest-and-longest-isekai-novel-title
# title:  What do you think is the dumbest and longest isekai / novel title
# author:  entrypoint78
# Inserted Thread-What-do-you-think-is-the-dumbest-and-longest-isekai-novel-title
# list index out of range
# scraping https://breachforums.vc/Forum-Giveaways-Freebies
# topic:  Thread-FREE-Latest-Offensive-Security-OSDA-SOC-200-complete-course-PDF-videos
# title:  [FREE] Latest Offensive Security OSDA / SOC-200 - complete course PDF + videos
# author:  Tamarisk
# Inserted Thread-FREE-Latest-Offensive-Security-OSDA-SOC-200-complete-course-PDF-videos
# list index out of range
# topic:  Thread-FREE-SANS-SEC595-Applied-Data-Science-and-Machine-Learning-complete-course
# title:  [FREE] SANS SEC595 Applied Data Science and Machine Learning - complete course
# author:  Tamarisk
# Inserted Thread-FREE-SANS-SEC595-Applied-Data-Science-and-Machine-Learning-complete-course
# list index out of range
# topic:  Thread-Free-Complete-Social-Engineering-Guide-for-beginners
# title:  [Free] Complete Social Engineering Guide for beginners
# author:  Marvel
# Inserted Thread-Free-Complete-Social-Engineering-Guide-for-beginners
# list index out of range
# topic:  Thread-FREE-Latest-Offensive-Security-OSWP-WiFu-PEN-210-complete-course-PDF
# title:  [FREE] Latest Offensive Security OSWP / WiFu / PEN-210 - complete course PDF
# author:  Tamarisk
# Inserted Thread-FREE-Latest-Offensive-Security-OSWP-WiFu-PEN-210-complete-course-PDF
# list index out of range
# topic:  Thread-PDF-Malware-Dev-AV-Evasion-Obfuscation-etc
# title:  [PDF] Malware Dev, AV Evasion, Obfuscation, etc.
# author:  violets
# Inserted Thread-PDF-Malware-Dev-AV-Evasion-Obfuscation-etc
# list index out of range
# topic:  Thread-Free-TCM-Security-Courses--67792
# title:  Free TCM Security Courses
# author:  ExamServices
# Inserted Thread-Free-TCM-Security-Courses--67792
# list index out of range
# topic:  Thread-Free-Spotify-Premium-for-Any-Account-Mobile-and-Desktop
# title:  Free Spotify Premium for Any Account (Mobile and Desktop)
# author:  KaBob
# Inserted Thread-Free-Spotify-Premium-for-Any-Account-Mobile-and-Desktop
# list index out of range
# topic:  Thread-List-of-useful-resources-for-pentesters-and-hackers
# title:  List of useful resources for pentesters and hackers
# author:  violets
# Inserted Thread-List-of-useful-resources-for-pentesters-and-hackers
# list index out of range
# topic:  Thread-FREE-CRTO-I-and-II-Red-Team-Ops-lessons-by-Zero-Point-Security
# title:  [FREE] CRTO I and II - Red Team Ops lessons by Zero-Point Security
# author:  Tamarisk
# Inserted Thread-FREE-CRTO-I-and-II-Red-Team-Ops-lessons-by-Zero-Point-Security
# list index out of range
# topic:  Thread-ENCCN-Ransomware-Builder-and-Tutorial
# title:  ENCCN Ransomware Builder and Tutorial
# author:  violets
# Inserted Thread-ENCCN-Ransomware-Builder-and-Tutorial
# list index out of range
# scraping https://breachforums.vc/Forum-Giveaways-Removed-Content
# scraping https://breachforums.vc/Forum-Music-Videos
# list index out of range
# topic:  Thread-Metal-or-Rock-recommendations
# title:  Metal or Rock recommendations
# author:  SSR147
# Inserted Thread-Metal-or-Rock-recommendations
# list index out of range
# topic:  Thread-Where-Do-You-Watch-Movies-and-Series
# title:  Where Do You Watch Movies and Series ?
# author:  Sanjuga
# Inserted Thread-Where-Do-You-Watch-Movies-and-Series
# list index out of range
# topic:  Thread-moonman-crank-dat
# title:  moonman - crank dat
# author:  moonman
# Inserted Thread-moonman-crank-dat
# list index out of range
# topic:  Thread-Best-Hip-hop-song
# title:  Best Hip-hop song
# author:  KenzieHowen
# Inserted Thread-Best-Hip-hop-song
# list index out of range
# topic:  Thread-Delta-Funktionen-Black-Endlessness-3
# title:  Delta Funktionen - Black Endlessness <3
# author:  SpotnikSignal
# Inserted Thread-Delta-Funktionen-Black-Endlessness-3
# list index out of range
# topic:  Thread-ZHEANI-SKIN-WALKER
# title:  ZHEANI - SKIN WALKER
# author:  SpotnikSignal
# Inserted Thread-ZHEANI-SKIN-WALKER
# list index out of range
# topic:  Thread-Techno-Melodic-vol-01-mix-by-MiniByte
# title:  Techno Melodic - vol. 01 - mix by MiniByte
# author:  MiniByte
# Inserted Thread-Techno-Melodic-vol-01-mix-by-MiniByte
# list index out of range
# topic:  Thread-Big-Time-Rush-Boyfriend
# title:  Big Time Rush - Boyfriend
# author:  Max
# Inserted Thread-Big-Time-Rush-Boyfriend
# list index out of range
# topic:  Thread-Lil-B-B-O-R-Birth-Of-Rap
# title:  Lil B - B.O.R.(Birth Of Rap)
# author:  imogen
# Inserted Thread-Lil-B-B-O-R-Birth-Of-Rap
# list index out of range
# scraping https://breachforums.vc/Forum-Programming
# list index out of range
# topic:  Thread-Chaturbate-Account-Creator-MAKE-MONEY-WITH-CHATURBATE
# title:  Chaturbate Account Creator [MAKE MONEY WITH CHATURBATE]
# author:  ryuzaki
# Inserted Thread-Chaturbate-Account-Creator-MAKE-MONEY-WITH-CHATURBATE
# list index out of range
# topic:  Thread-Do-you-like-BlackBox-code-chat
# title:  Do you like BlackBox -  code chat?
# author:  lord_x
# Inserted Thread-Do-you-like-BlackBox-code-chat
# list index out of range
# topic:  Thread-HIDE-YOUR-REAL-TELEGRAM-ACCOUNT-PYTHON
# title:  HIDE YOUR REAL TELEGRAM ACCOUNT [PYTHON]
# author:  black
# Inserted Thread-HIDE-YOUR-REAL-TELEGRAM-ACCOUNT-PYTHON
# list index out of range
# topic:  Thread-Looking-for-RUST-dev
# title:  Looking for RUST dev.
# author:  opsectard
# Inserted Thread-Looking-for-RUST-dev
# list index out of range
# topic:  Thread-Looking-for-REACT-dev
# title:  Looking for REACT dev.
# author:  opsectard
# Inserted Thread-Looking-for-REACT-dev
# list index out of range
# topic:  Thread-What-is-the-best-way-to-learn-C
# title:  What is the best way to learn C# ?
# author:  Mimibienv
# Inserted Thread-What-is-the-best-way-to-learn-C
# list index out of range
# topic:  Thread-Python-ExploitChoom-Fetch-Public-Exploits-From-CVE
# title:  [Python] ExploitChoom - Fetch Public Exploits From CVE
# author:  babyl0n
# Inserted Thread-Python-ExploitChoom-Fetch-Public-Exploits-From-CVE
# list index out of range
# topic:  Thread-how-to-learn-backend-i-have-done-react-js
# title:  how to learn backend? i have done react.js
# author:  tunknown02
# Inserted Thread-how-to-learn-backend-i-have-done-react-js
# list index out of range
# topic:  Thread-Next-js-vs-Node-js
# title:  Next.js vs Node.js?
# author:  tunknown02
# Inserted Thread-Next-js-vs-Node-js
# list index out of range
# topic:  Thread-Pegasus-Lime-HVNC-Bug-Fix-and-Patched
# title:  Pegasus Lime HVNC | Bug Fix and Patched
# author:  Calypso
# Inserted Thread-Pegasus-Lime-HVNC-Bug-Fix-and-Patched
# scraping https://breachforums.vc/Forum-Stealer-Logs
# topic:  Thread-30GB-compressed-logs-from-today
# title:  30GB compressed logs from today
# author:  k8gE3AQJ
# Inserted Thread-30GB-compressed-logs-from-today
# list index out of range
# topic:  Thread-Nearly-100-fresh-logs-world-mix-Juicey-info-in-PDFs
# title:  Nearly 100 fresh logs - world mix. Juicey info in PDFs
# author:  RottenSec
# Inserted Thread-Nearly-100-fresh-logs-world-mix-Juicey-info-in-PDFs
# list index out of range
# topic:  Thread-1400-Mixed-Stealer-Logs
# title:  1400 Mixed Stealer Logs
# author:  kokotheclown
# Inserted Thread-1400-Mixed-Stealer-Logs
# list index out of range
# topic:  Thread-900-Redline-Stealer-Logs-Leaked-Download
# title:  900+ Redline Stealer Logs - Leaked, Download!
# author:  bye
# Inserted Thread-900-Redline-Stealer-Logs-Leaked-Download
# list index out of range
# topic:  Thread-SORTED-LOGS-4gb-Archive-Passwords-Logs-Shops-Websites-Crypto-and-More
# title:  SORTED LOGS 4gb Archive | Passwords | Logs | Shops | Websites |Crypto and More.
# author:  Beelzebub
# Inserted Thread-SORTED-LOGS-4gb-Archive-Passwords-Logs-Shops-Websites-Crypto-and-More
# list index out of range
# topic:  Thread-8gb-URL-LOGIN-PASS
# title:  8gb+ URL:LOGIN:PASS
# author:  Beelzebub
# Inserted Thread-8gb-URL-LOGIN-PASS
# list index out of range
# topic:  Thread-753-logs-datacloudspace-zip
# title:  753 logs @datacloudspace.zip
# author:  Staples
# Inserted Thread-753-logs-datacloudspace-zip
# list index out of range
# topic:  Thread-REDLINE-FRESH-REDLINE-LOGS-16-JUNE-2023-Binance-BTC-Wallets-Accounts
# title:  [ REDLINE ] FRESH REDLINE LOGS 16 JUNE 2023 | Binance | BTC Wallets | Accounts
# author:  GovDz
# Inserted Thread-REDLINE-FRESH-REDLINE-LOGS-16-JUNE-2023-Binance-BTC-Wallets-Accounts
# list index out of range
# topic:  Thread-300k-url-user-pass
# title:  300k url:user:pass
# author:  Staples
# Inserted Thread-300k-url-user-pass
# list index out of range
# topic:  Thread-REDLINE-FRESH-400MB-REDLINE-LOGS-15-JUNE-2023-Binance-BTC-Wallets-Accounts
# title:  [ REDLINE ] FRESH 400MB REDLINE LOGS 15 JUNE 2023 | Binance | BTC Wallets | Accounts
# author:  GovDz
# Inserted Thread-REDLINE-FRESH-400MB-REDLINE-LOGS-15-JUNE-2023-Binance-BTC-Wallets-Accounts
# list index out of range
# scraping https://breachforums.vc/Forum-Other-Leaks
# topic:  Thread-TORRENT-MSI-Manufacturer
# title:  TORRENT | MSI Manufacturer
# author:  GhostyTarget
# Inserted Thread-TORRENT-MSI-Manufacturer
# list index out of range
# topic:  Thread-Cobalt-Strike-4-8-Arsenal-KIt-2023
# title:  Cobalt Strike 4.8 + Arsenal KIt 2023
# author:  witchking
# Inserted Thread-Cobalt-Strike-4-8-Arsenal-KIt-2023
# list index out of range
# topic:  Thread-PSD-35-Country
# title:  PSD +35 Country !
# author:  GhostyTarget
# Inserted Thread-PSD-35-Country
# list index out of range
# topic:  Thread-19-cameras-in-Vietnam-IP-PORT-USER-PASS-with-snapshot-links
# title:  19 cameras in Vietnam IP:PORT,USER,PASS with snapshot links
# author:  maraud3r
# Inserted Thread-19-cameras-in-Vietnam-IP-PORT-USER-PASS-with-snapshot-links
# list index out of range
# topic:  Thread-China-Shanghai-ccp-members-2020
# title:  China Shanghai ccp members 2020
# author:  FazyMalone
# Inserted Thread-China-Shanghai-ccp-members-2020
# list index out of range
# topic:  Thread-150k-Turkish-mail-addres-and-password-leak
# title:  150k Turkish mail addres and password leak
# author:  leonisas
# Inserted Thread-150k-Turkish-mail-addres-and-password-leak
# list index out of range
# topic:  Thread-Free-passport-www-strattonfinance-com-au
# title:  Free passport (www.strattonfinance.com.au)
# author:  concac
# Inserted Thread-Free-passport-www-strattonfinance-com-au
# list index out of range
# topic:  Thread-car-hacking-course-by-sajawal-hacker
# title:  car hacking course by sajawal hacker
# author:  v3701
# Inserted Thread-car-hacking-course-by-sajawal-hacker
# list index out of range
# topic:  Thread-Hacking-Forums-Links
# title:  Hacking Forums' Links
# author:  johnripper
# Inserted Thread-Hacking-Forums-Links
# list index out of range
# topic:  Thread-Saudi-Investment-EXCEL-31k
# title:  Saudi Investment EXCEL 31k
# author:  Trevor
# Inserted Thread-Saudi-Investment-EXCEL-31k
# list index out of range
# scraping https://breachforums.vc/Forum-Cracked-Accounts
# topic:  Thread-50-ChatGPT-OpenAI-Premium-Accounts
# title:  50 ''ChatGPT'' OpenAI Premium Accounts
# author:  SYCOSUNNY
# Inserted Thread-50-ChatGPT-OpenAI-Premium-Accounts
# list index out of range
# topic:  Thread-Netflix-Premium-Account-Cookies-SYCOSUNNY
# title:  Netflix Premium Account Cookies | SYCOSUNNY
# author:  SYCOSUNNY
# Inserted Thread-Netflix-Premium-Account-Cookies-SYCOSUNNY
# list index out of range
# topic:  Thread-x643-Mega-nz-Accounts-Full-Fresh-Hits-All-Check
# title:  x643 Mega.nz Accounts | Full Fresh Hits | All Check
# author:  SYCOSUNNY
# Inserted Thread-x643-Mega-nz-Accounts-Full-Fresh-Hits-All-Check
# list index out of range
# topic:  Thread-x10-NETFLIX-PREMIUM-ACCS
# title:  x10 NETFLIX PREMIUM ACCS
# author:  HEROINWATER
# Inserted Thread-x10-NETFLIX-PREMIUM-ACCS
# list index out of range
# topic:  Thread-2MB-SIZE-CPANEL-ACCOUNT
# title:  2MB SIZE - CPANEL ACCOUNT
# author:  MustLeaks
# Inserted Thread-2MB-SIZE-CPANEL-ACCOUNT
# list index out of range
# topic:  Thread-Tiktok-Logs
# title:  Tiktok Logs
# author:  qqq
# Inserted Thread-Tiktok-Logs
# list index out of range
# topic:  Thread-AMAZON-748-ACC-VALID-UHQ-W-PAYMENT-METHOD
# title:  AMAZON] 748 ACC VALID UHQ W PAYMENT METHOD
# author:  Johnhana
# Inserted Thread-AMAZON-748-ACC-VALID-UHQ-W-PAYMENT-METHOD
# list index out of range
# topic:  Thread-1350-good-wordpress-admin-accounts
# title:  1350 good wordpress admin accounts
# author:  Marvel
# Inserted Thread-1350-good-wordpress-admin-accounts
# list index out of range
# topic:  Thread-NBA-COM-ACCS-x25
# title:  NBA.COM ACCS x25
# author:  HEROINWATER
# Inserted Thread-NBA-COM-ACCS-x25
# list index out of range
# topic:  Thread-51-Kb-CRYPTOCURRENCY-URL-LOGIN-PASS
# title:  51 Kb CRYPTOCURRENCY - URL:LOGIN:PASS
# author:  MustLeaks
# Inserted Thread-51-Kb-CRYPTOCURRENCY-URL-LOGIN-PASS
# list index out of range
# scraping https://breachforums.vc/Forum-Not-Safe-For-Work
# topic:  Thread-IDUBBBZ-S-GF-ANISA-JOMHA-LEAKED
# title:  IDUBBBZ'S GF ANISA JOMHA LEAKED
# author:  KaBob
# Inserted Thread-IDUBBBZ-S-GF-ANISA-JOMHA-LEAKED
# list index out of range
# topic:  Thread-20-YO-INSTAGRAM-ONLYFANS-ORIGINAL-LEAK
# title:  20 YO INSTAGRAM + ONLYFANS (ORIGINAL LEAK)
# author:  KaBob
# Inserted Thread-20-YO-INSTAGRAM-ONLYFANS-ORIGINAL-LEAK
# list index out of range
# topic:  Thread-19YO-INSTAGRAM-NUDES-ORIGINAL-LEAK
# title:  19YO INSTAGRAM NUDES (ORIGINAL LEAK)
# author:  KaBob
# Inserted Thread-19YO-INSTAGRAM-NUDES-ORIGINAL-LEAK
# list index out of range
# topic:  Thread-%E2%9C%A8-Hannah-Owo-Onlyfans-2021-Leak-Google-Drive-%E2%9C%A8
# title:  ✨ Hannah Owo Onlyfans 2021 Leak [Google Drive]✨
# author:  PK268
# Inserted Thread-%E2%9C%A8-Hannah-Owo-Onlyfans-2021-Leak-Google-Drive-%E2%9C%A8
# list index out of range
# topic:  Thread-%E2%9C%A8FIND-ANY-MODELS-LEAKS%E2%9C%A8OF-PATREON-CELEBS-MORE
# title:  ✨FIND ANY MODELS LEAKS✨OF/PATREON/CELEBS + MORE
# author:  eightswitch
# Inserted Thread-%E2%9C%A8FIND-ANY-MODELS-LEAKS%E2%9C%A8OF-PATREON-CELEBS-MORE
# list index out of range
# topic:  Thread-Corinna-Kopf-OnlyFans-Pool-Video
# title:  Corinna Kopf OnlyFans Pool Video
# author:  didiergala
# Inserted Thread-Corinna-Kopf-OnlyFans-Pool-Video
# list index out of range
# topic:  Thread-CORINNA-KOPF-RARE-MASTRUBATION
# title:  CORINNA KOPF RARE MASTRUBATION
# author:  didiergala
# Inserted Thread-CORINNA-KOPF-RARE-MASTRUBATION
# list index out of range
# topic:  Thread-Public-archiver-for-onlyfans-and-fansly-content
# title:  Public archiver for onlyfans and fansly content
# author:  petrogruzni77
# Inserted Thread-Public-archiver-for-onlyfans-and-fansly-content
# list index out of range
# topic:  Thread-BEST-PORN-SITES
# title:  BEST PORN SITES?
# author:  PaulZentorno12
# Inserted Thread-BEST-PORN-SITES
# list index out of range
# topic:  Thread-That-British-Girl-49-GB-OnlyFans
# title:  That British Girl 49 GB OnlyFans
# author:  testing
# Inserted Thread-That-British-Girl-49-GB-OnlyFans
# list index out of range
# scraping https://breachforums.vc/Forum-NSFW-Removed-Content
# topic:  Thread-Corinna-Kopf-OnlyFans-Shower-Video
# title:  Corinna Kopf OnlyFans Shower Video
# author:  didiergala
# Inserted Thread-Corinna-Kopf-OnlyFans-Shower-Video
# list index out of range
# topic:  Thread-Corinna-Kopf-OnlyFans-Combined-Links
# title:  Corinna Kopf OnlyFans Combined Links
# author:  didiergala
# Inserted Thread-Corinna-Kopf-OnlyFans-Combined-Links
# scraping https://breachforums.vc/Forum-Sellers-Place
# list index out of range
# topic:  Thread-SELLING-Indonesia-Government-Shell-Access-Admin-Access
# title:  Indonesia Government [Shell Access + Admin Access]
# author:  Milad
# Inserted Thread-SELLING-Indonesia-Government-Shell-Access-Admin-Access
# list index out of range
# topic:  Thread-SELLING-%E2%AD%90INSTAGRAM-CHEAPEST-AND-MOST-GUARANTEED-SERVICES%E2%AD%90
# title:  ⭐INSTAGRAM CHEAPEST AND MOST GUARANTEED SERVICES⭐
# author:  kurdo
# Inserted Thread-SELLING-%E2%AD%90INSTAGRAM-CHEAPEST-AND-MOST-GUARANTEED-SERVICES%E2%AD%90
# list index out of range
# topic:  Thread-SELLING-ROBLOX-PHISHING-SITE
# title:  ROBLOX PHISHING SITE
# author:  Tosti
# Inserted Thread-SELLING-ROBLOX-PHISHING-SITE
# list index out of range
# topic:  Thread-%E2%AD%90-Spamming-Course-Tools-Phishing-Sites-%E2%AD%90
# title:  ⭐ Spamming Course | Tools | Phishing Sites ⭐
# author:  HackingRealm
# Inserted Thread-%E2%AD%90-Spamming-Course-Tools-Phishing-Sites-%E2%AD%90
# list index out of range
# topic:  Thread-SELLING-Url-Login-Pass-Regulary-updates-huge-lists-from-millions-logs
# title:  Url:Login:Pass - Regulary updates / huge lists from millions logs
# author:  Actor
# Inserted Thread-SELLING-Url-Login-Pass-Regulary-updates-huge-lists-from-millions-logs
# list index out of range
# topic:  Thread-SELLING-803K-China-Shanghai-Bank-Database-For-Sale
# title:  803K - China Shanghai Bank Database For Sale
# author:  SilkRoad
# Inserted Thread-SELLING-803K-China-Shanghai-Bank-Database-For-Sale
# list index out of range
# topic:  Thread-SELLING-%E2%AD%90-JIGSAW-STEALER-%E2%AD%90
# title:  ⭐ JIGSAW STEALER ⭐
# author:  jigsaw
# Inserted Thread-SELLING-%E2%AD%90-JIGSAW-STEALER-%E2%AD%90
# list index out of range
# topic:  Thread-SELLING-INDONESIA-PHONE-NUMBER-REGISTRATION-DATA
# title:  INDONESIA PHONE NUMBER REGISTRATION DATA
# author:  black
# Inserted Thread-SELLING-INDONESIA-PHONE-NUMBER-REGISTRATION-DATA
# list index out of range
# topic:  Thread-SELLING-272MILLION-BPJS-DATA-ALL-INDONESIA-POPULATION
# title:  272MILLION BPJS DATA (ALL INDONESIA POPULATION)
# author:  black
# Inserted Thread-SELLING-272MILLION-BPJS-DATA-ALL-INDONESIA-POPULATION
# list index out of range
# topic:  Thread-SELLING-VPN-access-to-a-US-based-plastic-surgeon-company-with-5m-revenue
# title:  VPN access to a US-based plastic surgeon company with 5m $ revenue
# author:  jigsaw
# Inserted Thread-SELLING-VPN-access-to-a-US-based-plastic-surgeon-company-with-5m-revenue
# scraping https://breachforums.vc/Forum-Games
# topic:  Thread-OSEE-CERTIF
# title:  OSEE CERTIF
# author:  Raphgui
# Inserted Thread-OSEE-CERTIF
# list index out of range
# topic:  Thread-%C4%B0mgui-Loader-imgui-Source-Code
# title:  İmgui Loader + imgui Source Code
# author:  MinikAyicuhV5
# Inserted Thread-%C4%B0mgui-Loader-imgui-Source-Code
# list index out of range
# topic:  Thread-%E2%9C%A8How-to-get-any-game-for-free%E2%9C%A8
# title:  ✨How to get any game for free✨
# author:  omega69
# Inserted Thread-%E2%9C%A8How-to-get-any-game-for-free%E2%9C%A8
# list index out of range
# topic:  Thread-Minecraft-Plugin-Series-2-LiteBans-2-12-2
# title:  Minecraft Plugin Series #2 - LiteBans 2.12.2
# author:  Cipher
# Inserted Thread-Minecraft-Plugin-Series-2-LiteBans-2-12-2
# list index out of range
# topic:  Thread-VisualArts-Key-Source-code-leaks
# title:  VisualArts/Key Source code leaks
# author:  ShimaMiyako
# Inserted Thread-VisualArts-Key-Source-code-leaks
# scraping https://breachforums.vc/Forum-Databases
# topic:  Thread-IMPORTANT-READ-Add-to-official-requests
# title:  Add to official requests
# author:  Manitora
# Inserted Thread-IMPORTANT-READ-Add-to-official-requests
# list index out of range
# topic:  Thread-Hudapar-org-Entire-Database-Turkish-H%C3%BCdapar-Party
# title:  Hudapar.org Entire Database (Turkish Hüdapar Party)
# author:  osaka
# Inserted Thread-Hudapar-org-Entire-Database-Turkish-H%C3%BCdapar-Party
# list index out of range
# topic:  Thread-Shopit-to
# title:  Shopit.to
# author:  sidmeet
# Inserted Thread-Shopit-to
# list index out of range
# topic:  Thread-Database-Leaked-messapp-id
# title:  Database Leaked messapp.id
# author:  pongo
# Inserted Thread-Database-Leaked-messapp-id
# list index out of range
# topic:  Thread-Actual-Instagram-Scrape
# title:  Actual Instagram Scrape.
# author:  femboy
# Inserted Thread-Actual-Instagram-Scrape
# list index out of range
# topic:  Thread-SilverAgeComics-com-United-Stated-28k-Users
# title:  SilverAgeComics.com | United Stated | 28k Users
# author:  cateye84
# Inserted Thread-SilverAgeComics-com-United-Stated-28k-Users
# list index out of range
# topic:  Thread-INDONESIA-BSI-Bank-7-4M-Costumers-Mobile-Mail-Database-Leaked-Download
# title:  INDONESIA - BSI Bank 7,4M Costumers Mobile Mail Database Leaked, Download !
# author:  Mendung_Ireng
# Inserted Thread-INDONESIA-BSI-Bank-7-4M-Costumers-Mobile-Mail-Database-Leaked-Download
# list index out of range
# topic:  Thread-Russian-Gloria-Jeans-Database-3M-Leaked-Download
# title:  [Russian] Gloria Jeans Database 3M - Leaked, Download!
# author:  404
# Inserted Thread-Russian-Gloria-Jeans-Database-3M-Leaked-Download
# list index out of range
# topic:  Thread-Russian-Chitai-Gorod-Database-9-8M-Leaked-Download
# title:  [Russian] Chitai-Gorod Database 9.8M - Leaked, Download!
# author:  404
# Inserted Thread-Russian-Chitai-Gorod-Database-9-8M-Leaked-Download
# list index out of range
# topic:  Thread-2022-flipd-gg-aka-ogu-gg-ogusers-com-529-020
# title:  (2022) flipd.gg aka ogu.gg/ogusers.com 529,020
# author:  emo
# Inserted Thread-2022-flipd-gg-aka-ogu-gg-ogusers-com-529-020
# list index out of range
# scraping https://breachforums.vc/Forum-Official
# topic:  Thread-247Hire-Database-Leaked-Download
# title:  247Hire Database - Leaked, Download!
# author:  dedale
# Inserted Thread-247Hire-Database-Leaked-Download
# list index out of range
# topic:  Thread-EatStreet-Database-Leaked-Download
# title:  EatStreet Database - Leaked, Download!
# author:  dedale
# Inserted Thread-EatStreet-Database-Leaked-Download
# list index out of range
# topic:  Thread-Pemiblanc-Collection-Leaked-Download
# title:  Pemiblanc Collection - Leaked, Download!
# author:  dedale
# Inserted Thread-Pemiblanc-Collection-Leaked-Download
# list index out of range
# topic:  Thread-Warframe-Database-Leaked-Download
# title:  Warframe Database - Leaked, Download!
# author:  dedale
# Inserted Thread-Warframe-Database-Leaked-Download
# list index out of range
# topic:  Thread-Canva-Database-Leaked-Download
# title:  Canva Database - Leaked, Download!
# author:  dedale
# Inserted Thread-Canva-Database-Leaked-Download
# list index out of range
# topic:  Thread-Twitter-Partial-Database-Leaked-Download
# title:  Twitter (Partial) Database - Leaked, Download!
# author:  dedale
# Inserted Thread-Twitter-Partial-Database-Leaked-Download
# list index out of range
# topic:  Thread-COMELEC-Philippines-Voters-Database-Leaked-Download
# title:  COMELEC (Philippines Voters) Database - Leaked, Download!
# author:  dedale
# Inserted Thread-COMELEC-Philippines-Voters-Database-Leaked-Download
# list index out of range
# topic:  Thread-PoliceOne-Database-Leaked-Download
# title:  PoliceOne Database - Leaked, Download!
# author:  dedale
# Inserted Thread-PoliceOne-Database-Leaked-Download
# list index out of range
# topic:  Thread-NetEase-163-com-126-com-Database-Leaked-Download
# title:  NetEase(163.com & 126.com) Database - Leaked, Download!
# author:  dedale
# Inserted Thread-NetEase-163-com-126-com-Database-Leaked-Download
# list index out of range
# topic:  Thread-Bitcoin-Talk-Database-Leaked-Download
# title:  Bitcoin Talk Database - Leaked, Download!
# author:  dedale
# Inserted Thread-Bitcoin-Talk-Database-Leaked-Download
# list index out of range
# scraping https://breachforums.vc/Forum-Databases-Removed-Content
# topic:  Thread-364k-italiamilitare-it-Full-Database
# title:  364k - italiamilitare.it Full Database
# author:  GhostyTarget
# Inserted Thread-364k-italiamilitare-it-Full-Database
# list index out of range
# topic:  Thread-1M-CITIZENS-DATA-OF-INDONESIA
# title:  1M CITIZENS DATA OF INDONESIA
# author:  MinikAyicuhV5
# Inserted Thread-1M-CITIZENS-DATA-OF-INDONESIA
# list index out of range
# topic:  Thread-Starbucks-Leak--69108
# title:  Starbucks Leak
# author:  femboy
# Inserted Thread-Starbucks-Leak--69108
# list index out of range
# topic:  Thread-Blockchain-31-7M-Partial-Emails-2023-June
# title:  Blockchain 31.7M Partial Emails 2023 June
# author:  b0b3at
# Inserted Thread-Blockchain-31-7M-Partial-Emails-2023-June
# list index out of range
# topic:  Thread-REPOST-CSV-Ministry-of-Public-Health-of-Ecuador-COVID-19-Leaked
# title:  [REPOST] [CSV] Ministry of Public Health of Ecuador COVID-19 - Leaked
# author:  WHOAMI
# Inserted Thread-REPOST-CSV-Ministry-of-Public-Health-of-Ecuador-COVID-19-Leaked
# list index out of range
# topic:  Thread-Rentomojo-Leaked-Download
# title:  Rentomojo Leaked, Download!
# author:  G0LD
# Inserted Thread-Rentomojo-Leaked-Download
# list index out of range
# topic:  Thread-2022-taiwan-person-data
# title:  2022 taiwan person data
# author:  z34yt9999
# Inserted Thread-2022-taiwan-person-data
# list index out of range
# scraping https://breachforums.vc/Forum-Stealer-Logs-Removed-Content
# scraping https://breachforums.vc/Forum-Other-Leaks-Removed-Content
# topic:  Thread-%E2%AD%90-FREEPIK-STOCK-IMAGES-DOWNLOADER%E2%AD%90
# title:  ⭐ FREEPIK STOCK IMAGES DOWNLOADER⭐
# author:  omega69
# Inserted Thread-%E2%AD%90-FREEPIK-STOCK-IMAGES-DOWNLOADER%E2%AD%90
# scraping https://breachforums.vc/Forum-Database-Discussion
# topic:  Thread-Database-Requests
# title:  Database Requests
# author:  Manitora
# Inserted Thread-Database-Requests
# list index out of range
# topic:  Thread-ZAP-Hosting-Database
# title:  ZAP-Hosting Database
# author:  wumpus
# Inserted Thread-ZAP-Hosting-Database
# list index out of range
# topic:  Thread-Looking-for-email-Phone-from-German-companies-or-noraml-people
# title:  Looking for email:Phone from German companies or noraml people
# author:  undefined
# Inserted Thread-Looking-for-email-Phone-from-German-companies-or-noraml-people
# list index out of range
# topic:  Thread-Request-Mangadex-org-Database
# title:  [Request] Mangadex.org Database
# author:  gabexcretion
# Inserted Thread-Request-Mangadex-org-Database
# list index out of range
# topic:  Thread-Restoring-topics-with-leaks-from-bf
# title:  Restoring topics with leaks from bf
# author:  Addka72424
# Inserted Thread-Restoring-topics-with-leaks-from-bf
# list index out of range
# topic:  Thread-Request-Nelnet-Servicing
# title:  [Request] Nelnet Servicing
# author:  Sex
# Inserted Thread-Request-Nelnet-Servicing
# scraping https://breachforums.vc/Forum-Database-Discussion-Removed-Content
# topic:  Thread-Looking-for-two-good-pentesters-who-can-come-to-Dubai
# title:  Looking for two good pentesters who can come to Dubai
# author:  SamuraiD
# Inserted Thread-Looking-for-two-good-pentesters-who-can-come-to-Dubai
# scraping https://breachforums.vc/Forum-Combolists
# topic:  Thread-878K-POLAND-BASES-HQ-FRESH-COMBO
# title:  878K POLAND BASES HQ FRESH COMBO
# author:  Johnhana
# Inserted Thread-878K-POLAND-BASES-HQ-FRESH-COMBO
# list index out of range
# topic:  Thread-4M-MAIL-ACCESS-United-States
# title:  4M MAIL ACCESS United States
# author:  anonz3us
# Inserted Thread-4M-MAIL-ACCESS-United-States
# list index out of range
# topic:  Thread-USA-COMBO
# title:  USA COMBO
# author:  Crypt
# Inserted Thread-USA-COMBO
# list index out of range
# topic:  Thread-6-9M-FRESH-Combolist-Mix
# title:  6.9M FRESH Combolist Mix
# author:  anonz3us
# Inserted Thread-6-9M-FRESH-Combolist-Mix
# list index out of range
# topic:  Thread-Usa-Best--69038
# title:  Usa Best
# author:  Doby
# Inserted Thread-Usa-Best--69038
# list index out of range
# topic:  Thread-8M-Porn-Mixed-Domains-Email-Pass
# title:  8M Porn Mixed Domains [Email:Pass]
# author:  DragonWarrior
# Inserted Thread-8M-Porn-Mixed-Domains-Email-Pass
# list index out of range
# topic:  Thread-3MILLION-GMAIL-ACCOUNTS-USA-EMAILPASS
# title:  3MILLION GMAIL ACCOUNTS USA EMAILPASS
# author:  DragonWarrior
# Inserted Thread-3MILLION-GMAIL-ACCOUNTS-USA-EMAILPASS
# list index out of range
# topic:  Thread-basefex-com-combolist
# title:  basefex.com combolist
# author:  anonz3us
# Inserted Thread-basefex-com-combolist
# list index out of range
# topic:  Thread-%E2%9A%A1%EF%B8%8F-250BTINTERNET-CRYPTO-COMBO-1%E2%9A%A1%EF%B8%8F-Sponsored-By-Arcane-Cloud
# title:  ⚡️ 250BTINTERNET CRYPTO COMBO #1⚡️  | Sponsored By Arcane Cloud
# author:  Onism
# Inserted Thread-%E2%9A%A1%EF%B8%8F-250BTINTERNET-CRYPTO-COMBO-1%E2%9A%A1%EF%B8%8F-Sponsored-By-Arcane-Cloud
# list index out of range
# topic:  Thread-%E2%9A%A1%EF%B8%8F-1-5-Mail-Acces-USA-%E2%9A%A1%EF%B8%8F-Sponsored-By-Arcane-Cloud
# title:  ⚡️ 1.5 Mail Acces USA ⚡️  | Sponsored By Arcane Cloud
# author:  Onism
# Inserted Thread-%E2%9A%A1%EF%B8%8F-1-5-Mail-Acces-USA-%E2%9A%A1%EF%B8%8F-Sponsored-By-Arcane-Cloud
# list index out of range
# scraping https://breachforums.vc/Forum-Combolist-Removed-Content
# scraping https://breachforums.vc/Forum-Dumped-Doxes
# scraping https://breachforums.vc/Forum-Services
# list index out of range
# topic:  Thread-Selling-Sendgrid-Account
# title:  Selling Sendgrid Account
# author:  nest0r
# Inserted Thread-Selling-Sendgrid-Account
# list index out of range
# topic:  Thread-Doing-IG-ban
# title:  Doing IG ban
# author:  pool
# Inserted Thread-Doing-IG-ban
# list index out of range
# topic:  Thread-IntelligenceSec-An-OSINT-Search-Engine
# title:  IntelligenceSec (An OSINT "Search Engine")
# author:  loner
# Inserted Thread-IntelligenceSec-An-OSINT-Search-Engine
# list index out of range
# topic:  Thread-1-SMMFLARE-COM-%E2%AD%90-CHEAPEST-SMM-PANEL-%E2%AD%90-FB-IG-TWITTER-TIKTOK-YOUTUBE-MORE
# title:  [#1] SMMFLARE.COM ⭐ CHEAPEST SMM PANEL ⭐ FB, IG, TWITTER, TIKTOK, YOUTUBE & MORE!
# author:  SMMFLARE
# Inserted Thread-1-SMMFLARE-COM-%E2%AD%90-CHEAPEST-SMM-PANEL-%E2%AD%90-FB-IG-TWITTER-TIKTOK-YOUTUBE-MORE
# list index out of range
# topic:  Thread-OSINT-Dox-Services
# title:  OSINT/Dox Services
# author:  TheRingmaster
# Inserted Thread-OSINT-Dox-Services
# list index out of range
# topic:  Thread-Our-exchange-discord
# title:  Our exchange discord!
# author:  Panerabread
# Inserted Thread-Our-exchange-discord
# list index out of range
# topic:  Thread-Buk-SMS-Sender-Gateway-With-costum-SenderID
# title:  Buk SMS Sender-Gateway| With costum SenderID.
# author:  londonview
# Inserted Thread-Buk-SMS-Sender-Gateway-With-costum-SenderID
# list index out of range
# topic:  Thread-KYC-service-by-HotCat
# title:  KYC service by HotCat
# author:  HotCat
# Inserted Thread-KYC-service-by-HotCat
# list index out of range
# topic:  Thread-the-best-osint-lookup
# title:  the best osint lookup
# author:  Kira
# Inserted Thread-the-best-osint-lookup
# list index out of range
# topic:  Thread-FERNOZ-DRAINER-MOST-DEADLY-DRAINER
# title:  FERNOZ DRAINER, MOST DEADLY DRAINER
# author:  MEWZKING
# Inserted Thread-FERNOZ-DRAINER-MOST-DEADLY-DRAINER
# scraping https://breachforums.vc/Forum-Hosting-Services
# list index out of range
# topic:  Thread-AnonHost-xyz-Anonymous-VPS-VDS-and-dedicated-servers-for-any-purposes
# title:  AnonHost.xyz | Anonymous VPS/VDS and dedicated servers for any purposes
# author:  Research3r
# Inserted Thread-AnonHost-xyz-Anonymous-VPS-VDS-and-dedicated-servers-for-any-purposes
# list index out of range
# scraping https://breachforums.vc/Forum-Programming-Services
# list index out of range
# topic:  Thread-Cashback-Special-Checker-for-Logs-Make-money-with-logs-NO-1
# title:  Cashback Special Checker for Logs - Make money with logs NO#1
# author:  Actor
# Inserted Thread-Cashback-Special-Checker-for-Logs-Make-money-with-logs-NO-1
# list index out of range
# topic:  Thread-Python-Web-Development-Services-Your-Ultimate-Solution-for-Top-Notch-Projects
# title:  Python & Web Development Services | Your Ultimate Solution for Top-Notch Projects
# author:  ryuzaki
# Inserted Thread-Python-Web-Development-Services-Your-Ultimate-Solution-for-Top-Notch-Projects
# list index out of range
# topic:  Thread-Coding-Service-Python-Java-Bots-Brute-Reg-checker-etc
# title:  Coding Service [Python - Java] | [Bots,Brute/Reg checker etc]
# author:  FCracker
# Inserted Thread-Coding-Service-Python-Java-Bots-Brute-Reg-checker-etc
# list index out of range
# topic:  Thread-I-can-make-all-phishing-site-live-phishing-panel-with-telegram-crypto-drainers-etc
# title:  I can make all phishing site, live phishing panel with telegram, crypto drainers etc.
# author:  phishing
# Inserted Thread-I-can-make-all-phishing-site-live-phishing-panel-with-telegram-crypto-drainers-etc
# list index out of range
# scraping https://breachforums.vc/Forum-Sellers-Place
# list index out of range
# topic:  Thread-SELLING-Indonesia-Government-Shell-Access-Admin-Access
# title:  Indonesia Government [Shell Access + Admin Access]
# author:  Milad
# Inserted Thread-SELLING-Indonesia-Government-Shell-Access-Admin-Access
# list index out of range
# topic:  Thread-SELLING-%E2%AD%90INSTAGRAM-CHEAPEST-AND-MOST-GUARANTEED-SERVICES%E2%AD%90
# title:  ⭐INSTAGRAM CHEAPEST AND MOST GUARANTEED SERVICES⭐
# author:  kurdo
# Inserted Thread-SELLING-%E2%AD%90INSTAGRAM-CHEAPEST-AND-MOST-GUARANTEED-SERVICES%E2%AD%90
# list index out of range
# topic:  Thread-SELLING-ROBLOX-PHISHING-SITE
# title:  ROBLOX PHISHING SITE
# author:  Tosti
# Inserted Thread-SELLING-ROBLOX-PHISHING-SITE
# list index out of range
# topic:  Thread-%E2%AD%90-Spamming-Course-Tools-Phishing-Sites-%E2%AD%90
# title:  ⭐ Spamming Course | Tools | Phishing Sites ⭐
# author:  HackingRealm
# Inserted Thread-%E2%AD%90-Spamming-Course-Tools-Phishing-Sites-%E2%AD%90
# list index out of range
# topic:  Thread-SELLING-Url-Login-Pass-Regulary-updates-huge-lists-from-millions-logs
# title:  Url:Login:Pass - Regulary updates / huge lists from millions logs
# author:  Actor
# Inserted Thread-SELLING-Url-Login-Pass-Regulary-updates-huge-lists-from-millions-logs
# list index out of range
# topic:  Thread-SELLING-803K-China-Shanghai-Bank-Database-For-Sale
# title:  803K - China Shanghai Bank Database For Sale
# author:  SilkRoad
# Inserted Thread-SELLING-803K-China-Shanghai-Bank-Database-For-Sale
# list index out of range
# topic:  Thread-SELLING-%E2%AD%90-JIGSAW-STEALER-%E2%AD%90
# title:  ⭐ JIGSAW STEALER ⭐
# author:  jigsaw
# Inserted Thread-SELLING-%E2%AD%90-JIGSAW-STEALER-%E2%AD%90
# list index out of range
# topic:  Thread-SELLING-INDONESIA-PHONE-NUMBER-REGISTRATION-DATA
# title:  INDONESIA PHONE NUMBER REGISTRATION DATA
# author:  black
# Inserted Thread-SELLING-INDONESIA-PHONE-NUMBER-REGISTRATION-DATA
# list index out of range
# topic:  Thread-SELLING-272MILLION-BPJS-DATA-ALL-INDONESIA-POPULATION
# title:  272MILLION BPJS DATA (ALL INDONESIA POPULATION)
# author:  black
# Inserted Thread-SELLING-272MILLION-BPJS-DATA-ALL-INDONESIA-POPULATION
# list index out of range
# topic:  Thread-SELLING-VPN-access-to-a-US-based-plastic-surgeon-company-with-5m-revenue
# title:  VPN access to a US-based plastic surgeon company with 5m $ revenue
# author:  jigsaw
# Inserted Thread-SELLING-VPN-access-to-a-US-based-plastic-surgeon-company-with-5m-revenue
# scraping https://breachforums.vc/Forum-Verified-Leaks-Market
# scraping https://breachforums.vc/Forum-Buyers-Place
# list index out of range
# topic:  Thread-need-email-with-harvard-edu
# title:  need email with @harvard.edu
# author:  Stony
# Inserted Thread-need-email-with-harvard-edu
# list index out of range
# topic:  Thread-chat-gpt-account-5
# title:  chat gpt account $5
# author:  rich
# Inserted Thread-chat-gpt-account-5
# list index out of range
# topic:  Thread-BUYING-SAKURA-LOGS
# title:  BUYING SAKURA LOGS
# author:  antidotkom
# Inserted Thread-BUYING-SAKURA-LOGS
# list index out of range
# topic:  Thread-Purchase-any-database-in-Taiwan-Unlimited-budget
# title:  Purchase any database in Taiwan ! Unlimited budget
# author:  OKE
# Inserted Thread-Purchase-any-database-in-Taiwan-Unlimited-budget
# list index out of range
# topic:  Thread-Purchase-a-complete-database
# title:  Purchase a complete database
# author:  Goldminer
# Inserted Thread-Purchase-a-complete-database
# list index out of range
# topic:  Thread-BUYING-German-Bank-Logs
# title:  [BUYING] German Bank Logs
# author:  ZoneAK
# Inserted Thread-BUYING-German-Bank-Logs
# list index out of range
# topic:  Thread-BUYING-LOGS
# title:  BUYING LOGS
# author:  antidotkom
# Inserted Thread-BUYING-LOGS
# list index out of range
# topic:  Thread-People-From-New-Zealand
# title:  People From New Zealand
# author:  Killua
# Inserted Thread-People-From-New-Zealand
# list index out of range
# topic:  Thread-Fixed-matches
# title:  Fixed matches
# author:  psihedelias
# Inserted Thread-Fixed-matches
# list index out of range
# topic:  Thread-buy-Connecticut-State-SSN
# title:  buy Connecticut State SSN
# author:  henshouhuanying
# Inserted Thread-buy-Connecticut-State-SSN
# scraping https://breachforums.vc/Forum-Cracking
# scraping https://breachforums.vc/Forum-Cracking-Discussion
# scraping https://breachforums.vc/Forum-Cracking-Tutorials
# topic:  Thread-%E2%AD%90Sim-Swap-method%E2%AD%90-full-guide
# title:  ⭐Sim Swap method⭐ full guide
# author:  omega69
# Inserted Thread-%E2%AD%90Sim-Swap-method%E2%AD%90-full-guide
# list index out of range
# topic:  Thread-ADVANCED-CRACKING-VIDEO-TUTORIAL-PACK-CONFIG-MAKING-CRACKING-DORKING
# title:  ADVANCED CRACKING VIDEO TUTORIAL PACK | CONFIG MAKING | CRACKING | DORKING
# author:  omega69
# Inserted Thread-ADVANCED-CRACKING-VIDEO-TUTORIAL-PACK-CONFIG-MAKING-CRACKING-DORKING
# list index out of range
# topic:  Thread-Python-Programming-from-Zero-to-Guru-2020
# title:  Python Programming from Zero to Guru (2020)
# author:  secretleakbuyer
# Inserted Thread-Python-Programming-from-Zero-to-Guru-2020
# list index out of range
# topic:  Thread-19-Web-Server-Exploit-Payload-Examples-Use-Cases
# title:  19 Web Server Exploit Payload Examples & Use Cases
# author:  Cipher
# Inserted Thread-19-Web-Server-Exploit-Payload-Examples-Use-Cases
# list index out of range
# topic:  Thread-Install-shells-in-OpenFire-CVE-2023-32315
# title:  Install shells in OpenFire ( CVE-2023-32315 )
# author:  Kurd
# Inserted Thread-Install-shells-in-OpenFire-CVE-2023-32315
# list index out of range
# topic:  Thread-Paypal-Refunding-Method-100-WORKING-ANY-STORE-REFUND
# title:  Paypal Refunding Method 100% WORKING ANY STORE REFUND
# author:  Slash
# Inserted Thread-Paypal-Refunding-Method-100-WORKING-ANY-STORE-REFUND
# list index out of range
# scraping https://breachforums.vc/Forum-Cracking-Help
# scraping https://breachforums.vc/Forum-Premade-Configs
# list index out of range
# topic:  Thread-Hulu-Openbullet-Config
# title:  Hulu Openbullet Config
# author:  Ayoumo
# Inserted Thread-Hulu-Openbullet-Config
# list index out of range
# topic:  Thread-Sonfires-Configs
# title:  Sonfires Configs
# author:  Sonfire2
# Inserted Thread-Sonfires-Configs
# list index out of range
# topic:  Thread-SLOTUM-COM-SVB
# title:  SLOTUM.COM [SVB]
# author:  HEROINWATER
# Inserted Thread-SLOTUM-COM-SVB
# scraping https://breachforums.vc/Forum-Defacements
# list index out of range
# topic:  Thread-m40rifle-com
# title:  m40rifle.com
# author:  kilob
# Inserted Thread-m40rifle-com
# scraping https://breachforums.vc/Forum-Tutorials
# scraping https://breachforums.vc/Forum-Doxing-Tutorials
# list index out of range
# topic:  Thread-HQ-DOXING-BIBLE-36-PAGES
# title:  HQ DOXING BIBLE | 36 PAGES
# author:  pongo
# Inserted Thread-HQ-DOXING-BIBLE-36-PAGES
# list index out of range
# topic:  Thread-Doxing-Guide-For-Beginners
# title:  Doxing Guide For Beginners
# author:  DragonWarrior
# Inserted Thread-Doxing-Guide-For-Beginners
# list index out of range
# topic:  Thread-8-Best-OSINT-Tools-for-2023
# title:  8 Best OSINT Tools for 2023
# author:  pongo
# Inserted Thread-8-Best-OSINT-Tools-for-2023
# list index out of range
# topic:  Thread-1-OSINT-Conducting-OSINT-on-Social-Media-Accounts
# title:  #1 OSINT  (Conducting OSINT on Social Media Accounts)
# author:  SSR147
# Inserted Thread-1-OSINT-Conducting-OSINT-on-Social-Media-Accounts
# list index out of range
# topic:  Thread-Search-Engines-for-collecting-databreaches-informations-OSINT
# title:  Search Engines for collecting databreaches informations (OSINT)
# author:  fair
# Inserted Thread-Search-Engines-for-collecting-databreaches-informations-OSINT
# list index out of range
# scraping https://breachforums.vc/Forum-Coding-Tutorials
# list index out of range
# topic:  Thread-Learning-Python-Ebook
# title:  Learning Python Ebook
# author:  DragonWarrior
# Inserted Thread-Learning-Python-Ebook
# list index out of range
# topic:  Thread-Download-page-as-pdf-in-python
# title:  Download page as pdf in python
# author:  specter
# Inserted Thread-Download-page-as-pdf-in-python
# list index out of range
# topic:  Thread-Current-city-weather-using-python
# title:  Current city weather using python
# author:  specter
# Inserted Thread-Current-city-weather-using-python
# list index out of range
# topic:  Thread-color-to-BW-convert-using-python
# title:  color to BW convert using python
# author:  specter
# Inserted Thread-color-to-BW-convert-using-python
# list index out of range
# topic:  Thread-Efficient-Vulnerability-Report-Cleanup-Script-for-xss-report
# title:  Efficient Vulnerability Report Cleanup Script for xss.report
# author:  Skynet
# Inserted Thread-Efficient-Vulnerability-Report-Cleanup-Script-for-xss-report
# list index out of range
# topic:  Thread-PlayStation-log-checker-python-code
# title:  PlayStation log checker python code
# author:  secretleakbuyer
# Inserted Thread-PlayStation-log-checker-python-code
# list index out of range
# topic:  Thread-Python-Website-Analyzer
# title:  Python Website Analyzer
# author:  secretleakbuyer
# Inserted Thread-Python-Website-Analyzer
# list index out of range
# topic:  Thread-script-Telegram-logs-to-tdata
# title:  [script] Telegram logs to tdata
# author:  secretleakbuyer
# Inserted Thread-script-Telegram-logs-to-tdata
# list index out of range
# topic:  Thread-script-Telegram-backup-offline-version
# title:  [script] Telegram backup (offline version)
# author:  secretleakbuyer
# Inserted Thread-script-Telegram-backup-offline-version
# list index out of range
# scraping https://breachforums.vc/Forum-General-Tutorials
# list index out of range
# topic:  Thread-%E2%AD%90HOW-TO-STAY-ANONYMOUS%E2%AD%90-FULL-GUIDE
# title:  ⭐HOW TO STAY ANONYMOUS⭐ FULL GUIDE
# author:  omega69
# Inserted Thread-%E2%AD%90HOW-TO-STAY-ANONYMOUS%E2%AD%90-FULL-GUIDE
# list index out of range
# topic:  Thread-How%E2%80%8B-to%E2%80%8B-make%E2%80%8B-a-mining%E2%80%8B-botnet
# title:  How​ to​ make​ a mining​ botnet
# author:  nitrogen
# Inserted Thread-How%E2%80%8B-to%E2%80%8B-make%E2%80%8B-a-mining%E2%80%8B-botnet
# list index out of range
# topic:  Thread-Ai-porn-picture-generator-SUPER-REALISTIC-good-for-E-whoring-%E2%9C%85
# title:  Ai porn picture generator - SUPER REALISTIC - good for E-whoring ✅
# author:  Jesus
# Inserted Thread-Ai-porn-picture-generator-SUPER-REALISTIC-good-for-E-whoring-%E2%9C%85
# list index out of range
# topic:  Thread-PASTEBIN-SEARCH-%E2%9A%A1FIND-ANYTHING-ON-PASTEBIN
# title:  PASTEBIN SEARCH ⚡FIND ANYTHING ON PASTEBIN
# author:  omega69
# Inserted Thread-PASTEBIN-SEARCH-%E2%9A%A1FIND-ANYTHING-ON-PASTEBIN
# list index out of range
# topic:  Thread-Radware-s-DDoS-Handbook-The-Ultimate-Guide-to-Everything-You-Need-to-Know-about
# title:  Radware's DDoS Handbook - The Ultimate Guide to Everything You Need to Know about
# author:  nitrogen
# Inserted Thread-Radware-s-DDoS-Handbook-The-Ultimate-Guide-to-Everything-You-Need-to-Know-about
# list index out of range
# topic:  Thread-OFFENSIVE-SECURITY-WEB-300-AWAE-ADVANCED-WEB-ATTACKS-AND-EXPLOITATION
# title:  OFFENSIVE SECURITY - WEB-300: AWAE (ADVANCED WEB ATTACKS AND EXPLOITATION)
# author:  0x01
# Inserted Thread-OFFENSIVE-SECURITY-WEB-300-AWAE-ADVANCED-WEB-ATTACKS-AND-EXPLOITATION
# list index out of range
# topic:  Thread-How-to-Create-Unlimited-Gmail-Account-Without-Phone-Number-Verification
# title:  How to Create Unlimited Gmail Account Without Phone Number Verification
# author:  SSR147
# Inserted Thread-How-to-Create-Unlimited-Gmail-Account-Without-Phone-Number-Verification
# list index out of range
# topic:  Thread-How-to-download-any-video-on-any-webpage
# title:  How to download any video on any webpage
# author:  KaBob
# Inserted Thread-How-to-download-any-video-on-any-webpage
# list index out of range
# topic:  Thread-The-Complete-Recreational-Drugs-Handbook
# title:  The Complete Recreational Drugs Handbook
# author:  kickassmiles
# Inserted Thread-The-Complete-Recreational-Drugs-Handbook
# list index out of range
# topic:  Thread-Secrets-of-Meth-Manufacture-8th-Edition
# title:  Secrets of Meth Manufacture 8th Edition
# author:  kickassmiles
# Inserted Thread-Secrets-of-Meth-Manufacture-8th-Edition
# scraping https://breachforums.vc/Forum-SE-Tutorials
# list index out of range
# scraping https://breachforums.vc/Forum-PC
# scraping https://breachforums.vc/Forum-General--57
# list index out of range
# scraping https://breachforums.vc/Forum-Operating-Systems
# scraping https://breachforums.vc/Forum-GNU-Linux
# list index out of range
# topic:  Thread-Poll-What-Dekstop-OS-you-use
# title:  Poll: What Dekstop OS you use?
# author:  osaka
# Inserted Thread-Poll-What-Dekstop-OS-you-use
# scraping https://breachforums.vc/Forum-OS-X
# list index out of range
# scraping https://breachforums.vc/Forum-Software
# list index out of range
# scraping https://breachforums.vc/Forum-Hardware
# scraping https://breachforums.vc/Forum-Builds
# scraping https://breachforums.vc/Forum-Phones
# scraping https://breachforums.vc/Forum-General--66
# scraping https://breachforums.vc/Forum-Android
# scraping https://breachforums.vc/Forum-iOS
# list index out of range
# topic:  Thread-Bring-your-Jailbroken-iPhone-to-Defcon
# title:  Bring your Jailbroken iPhone to Defcon
# author:  ShiroKun
# Inserted Thread-Bring-your-Jailbroken-iPhone-to-Defcon
# list index out of range
# scraping https://breachforums.vc/Forum-Firmware
# scraping https://breachforums.vc/Forum-Staff
# scraping https://breachforums.vc/Forum-Scam-Reports
# topic:  Thread-Scam-Report-Template
# title:  Scam Report Template
# author:  Manitora
# Inserted Thread-Scam-Report-Template
# list index out of range
# scraping https://breachforums.vc/Forum-Archives
# scraping https://breachforums.vc/Forum-Staff-Applications
# list index out of range
# topic:  Thread-Cipher-s-Staff-Application
# title:  Cipher's Staff Application
# author:  Cipher
# Inserted Thread-Cipher-s-Staff-Application
# list index out of range
# topic:  Thread-Staff-Application--68496
# title:  Staff Application
# author:  Paris
# Inserted Thread-Staff-Application--68496
# list index out of range
# topic:  Thread-Raid-s-Staff-Application
# title:  Raid's Staff Application
# author:  raid
# Inserted Thread-Raid-s-Staff-Application
# list index out of range
# topic:  Thread-Daisy-s-Staff-Application
# title:  Daisy's Staff Application
# author:  daisy
# Inserted Thread-Daisy-s-Staff-Application
# list index out of range
# topic:  Thread-Koko-s-Staff-Application
# title:  Koko's Staff Application
# author:  kokotheclown
# Inserted Thread-Koko-s-Staff-Application
# list index out of range
# topic:  Thread-kilob-s-staff-application
# title:  kilob's staff application
# author:  kilob
# Inserted Thread-kilob-s-staff-application
# scraping https://breachforums.vc/Forum-Denied-Applications
